# %% [markdown]
# # Setup

# %%
from tqdm import tqdm
import pandas as pd
import numpy as np
from nltk.tokenize import RegexpTokenizer
import glob
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# # Data

# %%
path =r'./cleaned_data/' # use your path
allFiles = glob.glob(path + "/*.csv")
df = pd.DataFrame()

list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None)
    list_.append(df)

df = pd.concat(list_)
df.reset_index(inplace=True, drop=True)

# %%
df.head()
# Out:
#     timestamp  category_id  topic_id  \
# 0  1514379921           57   2653937
# 1  1514380918           57   2653937
# 2  1514381025           57   2653937
# 3  1514382464           57   2653937
# 4  1514384271           57   2653937
#
#                                     topic_title  message_number  \
# 0  16.5K will be the major resistance for BTC ?               1
# 1  16.5K will be the major resistance for BTC ?               2
# 2  16.5K will be the major resistance for BTC ?               3
# 3  16.5K will be the major resistance for BTC ?               4
# 4  16.5K will be the major resistance for BTC ?               5
#
#     message_author                                       message_text  \
# 0  AICoin_Official  As you can see, price started a correction imm...
# 1           nokati  And&nbsp; who is this Kuang Ren with such a wi...
# 2         fabiorem  Yes, theres a lot of resistance at this level,...
# 3       heringasem  With the current price fluctuations the price ...
# 4        CuDoCuDau                             You should buy bitcoin
#
#                                          quoteheader
# 0                                                NaN
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  ['<div class="quoteheader"><a href="https://bi...

# %%
df.tail()
# Out:
#         timestamp  category_id  topic_id topic_title  message_number  \
# 41323  1411050454           57    787222           .               2
# 41324  1411050918           57    787222           .               3
# 41325  1411051112           57    787222           .               4
# 41326  1411075852           57    787222           .               5
# 41327  1411075887           57    787222           .               6
#
#          message_author                                       message_text  \
# 41323           Hfertig       And back down to 8365 without a short squ...
# 41324              klee                    So what is their next move? Up?
# 41325           Hfertig       Difficult to say. Selling pressure is sti...
# 41326         molecular       doesn't the same go for the $20 millions ...
# 41327  grappa_barricata  If i may add something, a sizable part of the ...
#
#                                              quoteheader
# 41323  ['<div class="quoteheader"><a href="https://bi...
# 41324                                                 []
# 41325  ['<div class="quoteheader"><a href="https://bi...
# 41326  ['<div class="quoteheader"><a href="https://bi...
# 41327                                                 []

# %% [markdown]
# ---

# %% [markdown]
# # Message Concatenating:

# %%
grouped_topics = df.groupby(df.topic_title).groups

# %%
dict_topic = {}
for tit in tqdm(grouped_topics.keys()):
    sentence = (df.message_text[grouped_topics[tit]].values)
    dict_topic.update({tit: ''.join(str(v) for v in sentence) })
# Out:
# 100%|██████████| 1100/1100 [00:00<00:00, 1849.02it/s]

# %%
list_message = []
for i in dict_topic.keys():
    list_message.append(dict_topic[i])

# %% [markdown]
# -------------

# %% [markdown]
# # LDA

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')  #match any word characters until it reaches a non-word character, like a space.

# %%
raw = list_message[0].lower()
tokens = tokenizer.tokenize(raw)

# %% [markdown]
# # Stop words

# %%
from stop_words import get_stop_words

# create English stop words list
en_stop = get_stop_words('en')

# %%
# remove stop words from tokens
stopped_tokens = [i for i in tokens if not i in en_stop]
print(stopped_tokens)
# Out:
# ['even', 'saw', 'much', 'impact', 'upcoming', 'fork', 'predicted', '6', '7k', 'easily', 'end', 'year', 'nbsp', 'much', 'news', 'btc', 'lot', 'adoption', 'now', 'fork', 'getting', 'closer', 'everyone', 'dumping', 'alt', 'coins', 'buy', 'btc', 'get', 'free', 'nbsp', 'btg', 'coins', 'nbsp', 'created', 'selling', 'alt', 'coin', 'buying', 'frenzy', 'btc', 'dumped', 'decent', 'amount', 'alt', 'coins', 'last', 'week', 'dropped', '25', '60', '7', 'days', 'across', 'board', 'nbsp', 'sure', 'makes', 'great', 'buying', 'opportunity', 'alt', 'coins', 'nbsp', 'get', 'alts', 'cheaper', 'added', 'value', 'btc', 'buy', 'nbsp', 'btc', '1470', 'since', 'last', 'week', 'nbsp', 'o', 'nbsp', 'nbsp', 'smashed', '5k', 'barrier', 'like', 'didn', 't', 'exist', 'dont', 'see', '6k', 'barrier', 'either', 'kind', 'frenzy', '7k', 'likely', 'wouldn', 't', 'surprised', 'see', 'touch', '8k', 'btc', 'gold', 'thar', 'hills', 'nbsp', 'nbsp', 'd', 'nbsp', '1470', '1', 'week', 'huge', 'massive', 'next', 'step', '7000']

# %% [markdown]
# # Our words

# %%
remove_words = ['will','s' , 'nbsp', 't', 'com', 'http', 'amp', '1xnk8bc', 'href', 'oto', 'www' ,'m', 'import', 'li', 'b', 'style' , 'font', 'span','hr', 'd' , 'jpg','p']
stopped_tokens = [i for i in stopped_tokens if not i in remove_words]
print(stopped_tokens)
# Out:
# ['imageshack', 'us', 'img833', '4225', 'moonan', 'imageshack', 'us', 'img833', '4225', 'moonan', 'imageshack', 'us', 'photo', 'images', '833', 'moonan', 'imageshack', 'us', 'img197', '347', 'cycles', 'imageshack', 'us', 'img197', '347', 'cycles', 'imageshack', 'us', 'photo', 'images', '197', 'cycles', 'imageshack', 'us', 'img685', '9515', 'deadmoonv', 'imageshack', 'us', 'img685', '9515', 'deadmoonv', 'imageshack', 'us', 'photo', 'images', '685', 'deadmoonv', 'dunno', 'let', 'know', 'still', 'didnt', 'right', '111', 'guess', 'going', 'fc07', 'deviantart', 'net', 'fs50', '2009', '257', '9', 'angel_and_devil_love_by_kil4', 'fc07', 'deviantart', 'net', 'fs50', '2009', '257', '9', 'angel_and_devil_love_by_kil4', 'can', 'fall', 'love', 'cheap', 'coinwhat', 'software', 'interface', 'https', 'bitcointalk', 'org', 'index', 'php', 'topic', '6019', '0', 'imageshack', 'us', 'img717', '1008', 'bearwedge', 'imageshack', 'us', 'img717', '1008', 'bearwedge', 'imageshack', 'us', 'photo', 'images', '717', 'bearwedge', 'uploaded', 'imageshack', 'us', 'imageshack', 'us', 'hmm', 'looks', 'bad', 'still', 'room', '1', '2', 'rallies', 'breaks', 'though']

# %% [markdown]
# # Stemming

# %%
from nltk.stem.porter import PorterStemmer

# Create p_stemmer of class PorterStemmer
p_stemmer = PorterStemmer()

# %%
# stem token
stemmed_tokens = [p_stemmer.stem(i) for i in stopped_tokens]

print(stemmed_tokens)
# Out:
# ['even', 'saw', 'much', 'impact', 'upcom', 'fork', 'predict', '6', '7k', 'easili', 'end', 'year', 'much', 'news', 'btc', 'lot', 'adopt', 'now', 'fork', 'get', 'closer', 'everyon', 'dump', 'alt', 'coin', 'buy', 'btc', 'get', 'free', 'btg', 'coin', 'creat', 'sell', 'alt', 'coin', 'buy', 'frenzi', 'btc', 'dump', 'decent', 'amount', 'alt', 'coin', 'last', 'week', 'drop', '25', '60', '7', 'day', 'across', 'board', 'sure', 'make', 'great', 'buy', 'opportun', 'alt', 'coin', 'get', 'alt', 'cheaper', 'ad', 'valu', 'btc', 'buy', 'btc', '1470', 'sinc', 'last', 'week', 'o', 'smash', '5k', 'barrier', 'like', 'didn', 'exist', 'dont', 'see', '6k', 'barrier', 'either', 'kind', 'frenzi', '7k', 'like', 'wouldn', 'surpris', 'see', 'touch', '8k', 'btc', 'gold', 'thar', 'hill', 'd', '1470', '1', 'week', 'huge', 'massiv', 'next', 'step', '7000']

# %% [markdown]
# # tokenizing, removing stop words, stemmming

# %%
from collections import Counter

# %%
texts = []

remove_words = ['will','s' , 'nbsp', 't', 'com', 'http', 'amp', '1xnk8bc', 'href', 'oto', 'www',
                "m", "import",  "import", "http", "li", "b", "style" , "font", "span","hr", "d" , "jpg", "png" ]
map_words = {
    'btc': 'bitcoin',
    'better': 'good'
}
for msg in tqdm(range(len(list_message))):
    raw = list_message[msg].lower()
    tokens = tokenizer.tokenize(raw)
    
    stopped_tokens = [i for i in tokens if not i in en_stop]
    stopped_tokens = [i for i in stopped_tokens if not i in remove_words]
    stemmed_tokens = [p_stemmer.stem(i) for i in stopped_tokens]
    stemmed_tokens = [i for i in stemmed_tokens if not i in remove_words]
    stemmed_tokens = [i for i in stemmed_tokens if not i in en_stop]
    d = pd.DataFrame({'z': stemmed_tokens})
    stemmed_tokens = d.replace(map_words)['z'].tolist()
    texts.append(stemmed_tokens)
# Out:
# 100%|██████████| 1100/1100 [00:34<00:00, 31.79it/s]

# %%
map_words = {
    'us': 'bitcoin',
    'better': 'good'
}
d = pd.DataFrame({'z': stemmed_tokens})
d.replace(map_words)
# Out:
#               z
# 0    imageshack
# 1       bitcoin
# 2        img833
# 3          4225
# 4        moonan
# 5    imageshack
# 6       bitcoin
# 7        img833
# 8          4225
# 9        moonan
# 10   imageshack
# 11      bitcoin
# 12        photo
# 13         imag
# 14          833
# 15       moonan
# 16   imageshack
# 17      bitcoin
# 18       img197
# 19          347
# 20         cycl
# 21   imageshack
# 22      bitcoin
# 23       img197
# 24          347
# 25         cycl
# 26   imageshack
# 27      bitcoin
# 28        photo
# 29         imag
# ..          ...
# 89      bitcoin
# 90       img717
# 91         1008
# 92     bearwedg
# 93   imageshack
# 94      bitcoin
# 95       img717
# 96         1008
# 97     bearwedg
# 98   imageshack
# 99      bitcoin
# 100       photo
# 101        imag
# 102         717
# 103    bearwedg
# 104      upload
# 105  imageshack
# 106     bitcoin
# 107  imageshack
# 108     bitcoin
# 109         hmm
# 110        look
# 111         bad
# 112       still
# 113        room
# 114           1
# 115           2
# 116       ralli
# 117       break
# 118      though
#
# [119 rows x 1 columns]

# %%
print(d)
# Out:
#               z
# 0    imageshack
# 1            us
# 2        img833
# 3          4225
# 4        moonan
# 5    imageshack
# 6            us
# 7        img833
# 8          4225
# 9        moonan
# 10   imageshack
# 11           us
# 12        photo
# 13         imag
# 14          833
# 15       moonan
# 16   imageshack
# 17           us
# 18       img197
# 19          347
# 20         cycl
# 21   imageshack
# 22           us
# 23       img197
# 24          347
# 25         cycl
# 26   imageshack
# 27           us
# 28        photo
# 29         imag
# ..          ...
# 89           us
# 90       img717
# 91         1008
# 92     bearwedg
# 93   imageshack
# 94           us
# 95       img717
# 96         1008
# 97     bearwedg
# 98   imageshack
# 99           us
# 100       photo
# 101        imag
# 102         717
# 103    bearwedg
# 104      upload
# 105  imageshack
# 106          us
# 107  imageshack
# 108          us
# 109         hmm
# 110        look
# 111         bad
# 112       still
# 113        room
# 114           1
# 115           2
# 116       ralli
# 117       break
# 118      though
#
# [119 rows x 1 columns]

# %%
stemmed_tokens.head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# dtype: object

# %%
for i in (range(len(texts))):
    print(Counter(texts[i]).most_common(7))
    print('------------'+str(i))
# Out:
# [('bitcoin', 6), ('alt', 5), ('coin', 5), ('buy', 4), ('get', 3), ('week', 3), ('much', 2)]
# ------------0
# [('bitcoin', 79), ('china', 46), ('chines', 41), ('price', 26), ('exchang', 22), ('news', 21), ('peopl', 21)]
# ------------1
# [('bitcoin', 4), ('buy', 4), ('1', 4), ('still', 3), ('wait', 2), ('000', 2), ('sit', 2)]
# ------------2
# [('1', 3), ('real', 3), ('time', 3), ('million', 2), ('like', 2), ('day', 2), ('exchang', 2)]
# ------------3
# [('bitcoin', 8), ('level', 4), ('hit', 3), ('go', 3), ('wil', 2), ('12k', 2), ('today', 2)]
# ------------4
# [('html', 2), ('btctrade', 1), ('gonggao', 1), ('0410', 1), ('reddit', 1), ('r', 1), ('bitcoin', 1)]
# ------------5
# [('bitcoin', 12), ('bear', 10), ('one', 7), ('time', 6), ('buy', 6), ('think', 6), ('way', 5)]
# ------------6
# [('happen', 19), ('fork', 18), ('bitcoin', 14), ('hard', 11), ('1', 11), ('novemb', 10), ('go', 9)]
# ------------7
# [('sinc', 3), ('bitcoin', 2), ('000', 2), ('reach', 2), ('five', 2), ('time', 2), ('around', 2)]
# ------------8
# [('bank', 50), ('china', 40), ('bitcoin', 29), ('ban', 14), ('govern', 11), ('make', 9), ('can', 9)]
# ------------9
# [('bitcoin', 34), ('price', 22), ('go', 18), ('now', 17), ('thing', 13), ('can', 12), ('see', 12)]
# ------------10
# [('bitcoin', 13), ('price', 10), ('10k', 10), ('see', 7), ('wait', 6), ('happen', 6), ('year', 6)]
# ------------11
# [('bitcoin', 1), ('price', 1), ('250', 1), ('000', 1), ('end', 1), ('2020', 1), ('http', 1)]
# ------------12
# [('okcoin', 3), ('bitcoin', 2), ('price', 2), ('friday', 1), ('go', 1), ('extra', 1), ('sweet', 1)]
# ------------13
# [('bitcoin', 103), ('price', 74), ('worri', 39), ('drop', 37), ('just', 24), ('day', 23), ('1000', 20)]
# ------------14
# [('bitcoin', 38), ('price', 18), ('think', 15), ('time', 13), ('can', 12), ('now', 11), ('market', 11)]
# ------------15
# [('bitcoin', 101), ('price', 62), ('year', 45), ('reach', 28), ('2018', 26), ('can', 23), ('think', 23)]
# ------------16
# [('bitcoin', 18), ('price', 14), ('can', 10), ('now', 7), ('000', 7), ('go', 6), ('think', 6)]
# ------------17
# [('currenc', 10), ('bitcoin', 10), ('peopl', 6), ('fiat', 6), ('like', 5), ('seem', 4), ('time', 4)]
# ------------18
# [('bitcoin', 1), ('next', 1), ('stop', 1), ('50', 1), ('000', 1), ('http', 1), ('youtub', 1)]
# ------------19
# [('first', 1), ('time', 1), ('sold', 1), ('coin', 1), ('30', 1), ('buck', 1), ('pyou', 1)]
# ------------20
# [('bitcoin', 26), ('futur', 11), ('peopl', 10), ('predict', 9), ('can', 7), ('one', 6), ('long', 6)]
# ------------21
# [('market', 2), ('price', 1), ('action', 1), ('drop', 1), ('mani', 1), ('technic', 1), ('trader', 1)]
# ------------22
# [('bitcoin', 10), ('price', 7), ('like', 6), ('see', 6), ('news', 6), ('month', 6), ('300', 5)]
# ------------23
# [('bitcoin', 19), ('price', 16), ('reason', 6), ('buy', 5), ('rise', 5), ('news', 5), ('trade', 5)]
# ------------24
# [('buy', 63), ('trade', 59), ('bitcoin', 55), ('strategi', 44), ('price', 35), ('hold', 33), ('sell', 32)]
# ------------25
# [('bitcoin', 22), ('exchang', 10), ('china', 7), ('peopl', 7), ('chines', 7), ('can', 7), ('cash', 5)]
# ------------26
# [('bitcoin', 68), ('etf', 64), ('approv', 45), ('go', 30), ('get', 29), ('price', 26), ('time', 24)]
# ------------27
# [('bitcoin', 3), ('good', 3), ('news', 3), ('think', 3), ('bangladesh', 3), ('time', 3), ('go', 3)]
# ------------28
# [('debt', 20), ('currenc', 17), ('pretend', 12), ('money', 10), ('base', 9), ('gold', 9), ('phoni', 7)]
# ------------29
# [('xt', 38), ('bitcoin', 30), ('core', 16), ('altcoin', 15), ('chain', 12), ('fork', 10), ('creat', 10)]
# ------------30
# [('bitcoin', 129), ('price', 93), ('fork', 59), ('segwit2x', 40), ('happen', 35), ('can', 34), ('like', 32)]
# ------------31
# [('euro', 40), ('1', 19), ('greec', 15), ('think', 13), ('countri', 13), ('happen', 11), ('go', 9)]
# ------------32
# [('bitcoin', 16), ('limit', 16), ('valu', 11), ('maxim', 9), ('one', 9), ('node', 9), ('mean', 8)]
# ------------33
# [('bitcoin', 58), ('market', 18), ('valu', 16), ('exchang', 11), ('money', 11), ('asset', 10), ('volum', 9)]
# ------------34
# [('thread', 16), ('bitcoin', 15), ('pirat', 13), ('post', 9), ('ponzi', 8), ('specul', 7), ('see', 6)]
# ------------35
# [('bitcoin', 22), ('year', 13), ('000', 10), ('price', 9), ('happen', 8), ('can', 7), ('400', 6)]
# ------------36
# [('bitcoin', 18), ('exchang', 7), ('price', 5), ('news', 5), ('1', 5), ('order', 5), ('custom', 5)]
# ------------37
# [('imgur', 16), ('imag', 3), ('thread', 2), ('bntyiw', 2), ('av', 2), ('r', 2), ('ftdata', 2)]
# ------------38
# [('bitcoin', 163), ('price', 128), ('can', 48), ('buy', 36), ('increas', 33), ('peopl', 29), ('push', 28)]
# ------------39
# [('think', 2), ('bitcoin', 1), ('reach', 1), ('120', 1), ('000', 1), ('billionair', 1), ('say', 1)]
# ------------40
# [('gold', 25), ('bitcoin', 22), ('silver', 20), ('invest', 13), ('price', 13), ('buy', 9), ('way', 8)]
# ------------41
# [('bitcoin', 93), ('valu', 54), ('price', 50), ('think', 27), ('can', 24), ('demand', 18), ('time', 16)]
# ------------42
# [('price', 5), ('bitcoin', 3), ('apolog', 2), ('offend', 2), ('don', 2), ('time', 2), ('polit', 2)]
# ------------43
# [('hit', 2), ('cjgame', 2), ('download', 2), ('yeah', 1), ('now', 1), ('new', 1), ('price', 1)]
# ------------44
# [('bitcoin', 37), ('tax', 27), ('money', 24), ('get', 23), ('life', 22), ('just', 20), ('can', 17)]
# ------------45
# [('one', 2), ('bitcoinwisdom', 2), ('bitcoin', 1), ('alreadi', 1), ('100', 1), ('day', 1), ('know', 1)]
# ------------46
# [('bitcoin', 52), ('currenc', 48), ('price', 41), ('money', 41), ('can', 40), ('inflat', 35), ('peopl', 33)]
# ------------47
# [('translat', 3), ('bank', 3), ('money', 3), ('back', 3), ('english', 3), ('email', 2), ('spam', 2)]
# ------------48
# [('wall', 43), ('bitcoin', 40), ('price', 32), ('buy', 22), ('manipul', 22), ('2', 20), ('now', 17)]
# ------------49
# [('bitcoin', 91), ('price', 59), ('fork', 27), ('now', 22), ('go', 20), ('expect', 20), ('peopl', 17)]
# ------------50
# [('gif', 4), ('blockchain', 3), ('paywal', 2), ('googl', 2), ('utf', 2), ('8', 2), ('ledger', 2)]
# ------------51
# [('coin', 16), ('price', 16), ('bitcoin', 15), ('bearwhal', 14), ('market', 14), ('manipul', 11), ('bear', 10)]
# ------------52
# [('china', 60), ('exchang', 35), ('bitcoin', 27), ('can', 20), ('ban', 19), ('chines', 18), ('news', 16)]
# ------------53
# [('del', 6), ('bitcoin', 5), ('mtgox', 3), ('youtub', 2), ('watch', 2), ('v', 2), ('oieze6giwww', 2)]
# ------------54
# [('coin', 6), ('7', 4), ('chart', 4), ('blockchain', 4), ('news', 3), ('old', 3), ('younger', 3)]
# ------------55
# [('introduc', 4), ('bitcoin', 3), ('new', 3), ('median', 3), ('spread', 3), ('use', 3), ('bubbl', 2)]
# ------------56
# [('bitcoin', 49), ('price', 26), ('see', 17), ('now', 15), ('month', 15), ('year', 14), ('think', 14)]
# ------------57
# [('price', 10), ('news', 6), ('bitcoin', 4), ('articl', 4), ('outdat', 4), ('go', 4), ('increas', 3)]
# ------------58
# [('get', 8), ('bitstamp', 6), ('go', 5), ('time', 4), ('friday', 4), ('imag', 4), ('s9', 4)]
# ------------59
# [('bitcoin', 34), ('use', 16), ('safe', 14), ('comput', 12), ('peopl', 11), ('secur', 10), ('even', 9)]
# ------------60
# [('jeff', 5), ('just', 4), ('time', 4), ('http', 3), ('bitcoin', 3), ('like', 3), ('s32', 2)]
# ------------61
# [('bitcoin', 10), ('work', 10), ('just', 6), ('think', 6), ('believ', 5), ('know', 5), ('don', 5)]
# ------------62
# [('bitcoin', 68), ('bitpay', 37), ('fee', 36), ('valu', 30), ('price', 24), ('transact', 23), ('payment', 23)]
# ------------63
# [('bitcoin', 106), ('just', 26), ('think', 19), ('know', 18), ('make', 16), ('peopl', 16), ('like', 15)]
# ------------64
# [('bitcoin', 27), ('rich', 10), ('get', 9), ('quick', 9), ('andrea', 9), ('dead', 8), ('antonopoulo', 8)]
# ------------65
# [('posit', 13), ('bitcoinica', 10), ('account', 8), ('spread', 7), ('price', 7), ('just', 6), ('one', 5)]
# ------------66
# [('bitcoin', 77), ('dell', 33), ('accept', 25), ('price', 25), ('news', 23), ('can', 20), ('just', 19)]
# ------------67
# [('bitcoin', 7), ('make', 3), ('take', 3), ('post', 3), ('1', 3), ('runtogold', 2), ('imag', 2)]
# ------------68
# [('bitcoin', 24), ('like', 7), ('money', 6), ('peopl', 6), ('just', 5), ('look', 5), ('grandmoth', 4)]
# ------------69
# [('bitcoin', 20), ('price', 12), ('miner', 9), ('4', 7), ('one', 7), ('50', 5), ('can', 5)]
# ------------70
# [('user', 3), ('bitcoin', 3), ('d3', 3), ('gold', 3), ('trade', 3), ('forum', 3), ('1', 2)]
# ------------71
# [('bank', 3), ('buy', 2), ('clown', 1), ('global', 1), ('standard', 1), ('set', 1), ('sell', 1)]
# ------------72
# [('bitcoin', 17), ('news', 11), ('like', 9), ('now', 8), ('porn', 7), ('china', 6), ('good', 6)]
# ------------73
# [('bitcoin', 45), ('news', 24), ('price', 23), ('good', 15), ('accept', 11), ('peopl', 11), ('happen', 10)]
# ------------74
# [('lawnmow', 10), ('bitcoin', 9), ('price', 7), ('8202', 6), ('think', 4), ('just', 4), ('promot', 4)]
# ------------75
# [('bitcoin', 62), ('price', 19), ('invest', 19), ('wall', 18), ('street', 18), ('like', 18), ('bubbl', 15)]
# ------------76
# [('bitcoin', 33), ('time', 13), ('price', 7), ('just', 7), ('use', 6), ('good', 5), ('earli', 5)]
# ------------77
# [('bitcoin', 28), ('peopl', 15), ('poker', 13), ('get', 11), ('much', 10), ('like', 8), ('year', 8)]
# ------------78
# [('view', 2), ('interest', 2), ('market', 2), ('anyon', 1), ('els', 1), ('look', 1), ('ask', 1)]
# ------------79
# [('verifi', 17), ('bitcoin', 14), ('withdraw', 10), ('mtgox', 9), ('per', 8), ('limit', 7), ('account', 6)]
# ------------80
# [('bought', 6), ('price', 5), ('time', 4), ('thought', 3), ('didn', 3), ('bitcoin', 3), ('bubbl', 3)]
# ------------81
# [('bitcoin', 77), ('bitcoinica', 65), ('short', 60), ('posit', 51), ('long', 49), ('sell', 44), ('buy', 43)]
# ------------82
# [('bitcoin', 4), ('second', 2), ('market', 2), ('financi', 2), ('coinbas', 2), ('circl', 2), ('root', 2)]
# ------------83
# [('year', 6), ('trend', 5), ('tend', 3), ('usabl', 3), ('2019', 3), ('e', 2), ('gener', 2)]
# ------------84
# [('bitcoin', 7), ('bet', 6), ('year', 5), ('end', 5), ('2', 5), ('go', 5), ('1500', 4)]
# ------------85
# [('hour', 8), ('2', 6), ('hr', 5), ('direct', 5), ('go', 5), ('past', 4), ('move', 4)]
# ------------86
# [('chodpaba', 10), ('post', 9), ('time', 8), ('like', 8), ('see', 7), ('can', 5), ('still', 5)]
# ------------87
# [('factor', 3), ('step', 3), ('number', 2), ('15', 2), ('well', 2), ('quantum', 2), ('hand', 2)]
# ------------88
# [('bitcoin', 15), ('gox', 14), ('us', 13), ('wire', 12), ('dwolla', 11), ('just', 11), ('mtgox', 10)]
# ------------89
# [('bitcoin', 7), ('price', 7), ('manipul', 6), ('realli', 6), ('investor', 5), ('higher', 5), ('one', 5)]
# ------------90
# [('weekend', 18), ('price', 13), ('bitcoin', 10), ('good', 8), ('week', 7), ('time', 7), ('goe', 7)]
# ------------91
# [('bitcoin', 240), ('price', 102), ('valu', 73), ('can', 58), ('peopl', 55), ('overvalu', 46), ('use', 45)]
# ------------92
# [('bitcoin', 76), ('altcoin', 31), ('peopl', 18), ('can', 13), ('just', 13), ('think', 12), ('000', 12)]
# ------------93
# [('wallet', 45), ('bitcoin', 24), ('can', 16), ('exchang', 15), ('electrum', 14), ('safe', 13), ('coin', 12)]
# ------------94
# [('bitcoin', 49), ('bank', 20), ('like', 17), ('don', 14), ('just', 14), ('make', 11), ('think', 11)]
# ------------95
# [('buy', 3), ('sell', 3), ('read', 3), ('went', 2), ('fortun', 2), ('teller', 2), ('took', 2)]
# ------------96
# [('bitcoin', 72), ('stock', 33), ('price', 26), ('market', 22), ('think', 21), ('correl', 15), ('go', 15)]
# ------------97
# [('bitcoin', 8), ('chart', 4), ('like', 4), ('back', 3), ('bitcoinchart', 3), ('re', 2), ('new', 2)]
# ------------98
# [('bitcoin', 19), ('even', 5), ('circl', 4), ('peopl', 4), ('want', 4), ('get', 4), ('invest', 3)]
# ------------99
# [('unknown', 5), ('topic', 4), ('right', 3), ('now', 3), ('hashrat', 3), ('50', 3), ('pool', 3)]
# ------------100
# [('bitcoin', 2), ('lower', 2), ('test', 2), ('support', 2), ('zone', 2), ('look', 1), ('like', 1)]
# ------------101
# [('know', 2), ('cash', 2), ('pretti', 2), ('amaz', 2), ('nani', 1), ('dont', 1), ('don', 1)]
# ------------102
# [('bitcoin', 9), ('u', 8), ('peopl', 7), ('sell', 6), ('can', 4), ('look', 4), ('hype', 3)]
# ------------103
# [('bitcoin', 42), ('price', 27), ('market', 25), ('pirat', 25), ('sell', 17), ('go', 16), ('just', 13)]
# ------------104
# [('bitcoin', 16), ('1', 14), ('just', 13), ('000', 9), ('1000', 9), ('like', 9), ('now', 7)]
# ------------105
# [('220', 4), ('number', 2), ('reason', 2), ('parti', 2), ('topic', 1), ('need', 1), ('stock', 1)]
# ------------106
# [('bitcoin', 17), ('can', 15), ('just', 8), ('peopl', 7), ('valu', 6), ('get', 6), ('price', 6)]
# ------------107
# [('imag', 5), ('bitcoin', 5), ('look', 4), ('us', 3), ('lol', 3), ('go', 3), ('postimg', 3)]
# ------------108
# [('year', 24), ('price', 23), ('bitcoin', 19), ('1000', 17), ('end', 11), ('2017', 9), ('think', 9)]
# ------------109
# [('bitcoin', 74), ('price', 30), ('can', 16), ('happen', 16), ('think', 15), ('2020', 14), ('peopl', 13)]
# ------------110
# [('bubbl', 38), ('x', 28), ('5', 27), ('2', 26), ('15', 19), ('1', 17), ('3', 17)]
# ------------111
# [('100', 3), ('new', 2), ('2011', 2), ('see', 2), ('bubbl', 2), ('57', 2), ('3', 2)]
# ------------112
# [('bitcoin', 64), ('1', 19), ('think', 18), ('year', 18), ('valu', 16), ('like', 15), ('peopl', 14)]
# ------------113
# [('1', 2), ('number', 2), ('bitcoin', 2), ('blockchain', 2), ('congratul', 1), ('just', 1), ('reach', 1)]
# ------------114
# [('bitcoin', 64), ('1', 23), ('price', 23), ('can', 19), ('even', 19), ('happen', 18), ('million', 14)]
# ------------115
# [('bitcoin', 122), ('can', 46), ('000', 37), ('money', 32), ('think', 26), ('1', 26), ('just', 26)]
# ------------116
# [('bitcoin', 19), ('price', 10), ('money', 9), ('1', 8), ('buy', 8), ('time', 8), ('000', 8)]
# ------------117
# [('bitcoin', 70), ('price', 52), ('go', 37), ('think', 36), ('7000', 33), ('1800', 30), ('can', 28)]
# ------------118
# [('gold', 6), ('000', 5), ('bitcoin', 5), ('ant', 5), ('21', 4), ('million', 4), ('buy', 4)]
# ------------119
# [('bitcoin', 30), ('sell', 22), ('exchang', 18), ('price', 17), ('market', 17), ('bitpay', 12), ('1', 11)]
# ------------120
# [('inherit', 162), ('td', 160), ('color', 81), ('valign', 80), ('top', 80), ('tr', 40), ('10', 30)]
# ------------121
# [('new', 9), ('10', 7), ('15', 5), ('gif', 4), ('bitcoin', 4), ('stabl', 3), ('price', 3)]
# ------------122
# [('bitcoin', 47), ('market', 41), ('price', 38), ('bot', 28), ('go', 19), ('ask', 18), ('wall', 17)]
# ------------123
# [('bitcoin', 19), ('price', 12), ('peopl', 8), ('go', 8), ('000', 6), ('rise', 5), ('usd', 5)]
# ------------124
# [('bitcoin', 34), ('price', 24), ('000', 12), ('reach', 10), ('10', 7), ('keiser', 6), ('just', 6)]
# ------------125
# [('bitcoin', 56), ('price', 34), ('10', 28), ('000', 28), ('10k', 17), ('see', 15), ('reach', 14)]
# ------------126
# [('bitcoin', 19), ('bet', 18), ('000', 10), ('like', 10), ('10', 9), ('2016', 9), ('year', 8)]
# ------------127
# [('bitcoin', 150), ('price', 77), ('2018', 47), ('year', 45), ('can', 41), ('happen', 36), ('reach', 35)]
# ------------128
# [('bubbl', 25), ('bitcoin', 22), ('000', 22), ('year', 20), ('10', 20), ('month', 15), ('price', 14)]
# ------------129
# [('http', 2), ('bitcointalk', 2), ('org', 2), ('index', 2), ('php', 2), ('topic', 2), ('0', 2)]
# ------------130
# [('bitcoin', 342), ('price', 248), ('year', 164), ('happen', 127), ('reach', 126), ('think', 117), ('can', 116)]
# ------------131
# [('bitcoin', 246), ('price', 159), ('year', 92), ('reach', 58), ('can', 57), ('happen', 55), ('think', 53)]
# ------------132
# [('bitcoin', 45), ('year', 15), ('can', 14), ('price', 14), ('000', 12), ('10k', 10), ('think', 10)]
# ------------133
# [('bitcoin', 31), ('year', 16), ('000', 14), ('time', 13), ('get', 11), ('10', 10), ('10k', 10)]
# ------------134
# [('bitcoin', 49), ('year', 42), ('think', 22), ('3', 19), ('price', 18), ('chanc', 14), ('000', 14)]
# ------------135
# [('bitcoin', 69), ('etf', 45), ('price', 28), ('get', 26), ('can', 23), ('think', 21), ('like', 19)]
# ------------136
# [('bitcoin', 73), ('price', 26), ('10k', 25), ('10', 23), ('year', 21), ('think', 19), ('dream', 18)]
# ------------137
# [('bitcoin', 209), ('price', 133), ('year', 123), ('think', 54), ('new', 50), ('now', 49), ('10k', 47)]
# ------------138
# [('happen', 5), ('next', 5), ('year', 4), ('10k', 4), ('bubbl', 3), ('bitcoin', 3), ('learn', 2)]
# ------------139
# [('relev', 1), ('youtub', 1), ('watch', 1), ('v', 1), ('bi93hceafemwond', 1), ('4', 1), ('20', 1)]
# ------------140
# [('bitcoin', 35), ('100', 26), ('coin', 17), ('buy', 15), ('price', 15), ('think', 14), ('like', 13)]
# ------------141
# [('bitcoin', 5), ('buy', 4), ('sell', 4), ('just', 3), ('use', 3), ('price', 2), ('800', 2)]
# ------------142
# [('bitcoin', 34), ('peopl', 26), ('price', 23), ('go', 20), ('think', 19), ('buy', 16), ('see', 15)]
# ------------143
# [('bitcoin', 14), ('2016', 8), ('happen', 7), ('000', 5), ('just', 5), ('much', 5), ('thing', 5)]
# ------------144
# [('exchang', 13), ('bitcoin', 12), ('year', 10), ('price', 10), ('1000', 9), ('now', 8), ('hack', 7)]
# ------------145
# [('1000', 7), ('month', 6), ('hit', 5), ('think', 4), ('buy', 4), ('bitcoin', 3), ('price', 3)]
# ------------146
# [('bitcoin', 28), ('option', 24), ('delta', 12), ('1000', 11), ('buy', 11), ('can', 9), ('1', 9)]
# ------------147
# [('bitcoin', 27), ('1000', 27), ('peopl', 20), ('price', 18), ('think', 16), ('sell', 16), ('time', 12)]
# ------------148
# [('bitcoin', 11), ('price', 11), ('1000', 6), ('can', 6), ('happen', 5), ('buy', 5), ('back', 4)]
# ------------149
# [('bitcoin', 9), ('1000', 7), ('org', 5), ('us', 4), ('congrat', 4), ('tinyp', 4), ('postimg', 4)]
# ------------150
# [('can', 2), ('ath', 2), ('see', 2), ('day', 2), ('hold', 1), ('1000', 1), ('predict', 1)]
# ------------151
# [('bitcoin', 181), ('price', 90), ('year', 60), ('think', 45), ('2024', 44), ('happen', 44), ('reach', 39)]
# ------------152
# [('price', 40), ('1000', 32), ('bitcoin', 31), ('new', 27), ('floor', 25), ('can', 17), ('go', 14)]
# ------------153
# [('price', 39), ('bitcoin', 34), ('difficulti', 22), ('miner', 17), ('mine', 14), ('hashrat', 12), ('increas', 9)]
# ------------154
# [('price', 26), ('dump', 21), ('bitcoin', 21), ('order', 14), ('just', 12), ('whale', 10), ('see', 10)]
# ------------155
# [('bitcoin', 162), ('price', 160), ('year', 82), ('10k', 56), ('can', 50), ('end', 48), ('think', 46)]
# ------------156
# [('bitcoin', 145), ('price', 76), ('decemb', 48), ('reach', 43), ('10k', 38), ('now', 35), ('year', 31)]
# ------------157
# [('bitcoin', 43), ('price', 26), ('possibl', 23), ('usd', 22), ('year', 21), ('2016', 19), ('think', 16)]
# ------------158
# [('bear', 5), ('hack', 4), ('year', 4), ('end', 3), ('mayb', 3), ('5', 2), ('cage', 2)]
# ------------159
# [('bitcoin', 273), ('price', 143), ('year', 91), ('10k', 84), ('reach', 78), ('march', 71), ('2018', 64)]
# ------------160
# [('spend', 51), ('doubl', 43), ('bitcoin', 31), ('fork', 25), ('chain', 23), ('transact', 21), ('merchant', 19)]
# ------------161
# [('bitcoin', 21), ('price', 20), ('10k', 13), ('reach', 6), ('peopl', 6), ('sell', 6), ('happen', 5)]
# ------------162
# [('price', 318), ('bitcoin', 304), ('year', 195), ('10k', 134), ('think', 122), ('happen', 118), ('reach', 116)]
# ------------163
# [('price', 22), ('bitcoin', 19), ('china', 12), ('ath', 11), ('see', 10), ('new', 10), ('now', 9)]
# ------------164
# [('1', 6), ('buy', 5), ('bottl', 5), ('scotch', 5), ('yet', 4), ('100', 4), ('000', 4)]
# ------------165
# [('bitcoin', 120), ('price', 113), ('now', 64), ('just', 50), ('go', 48), ('see', 46), ('correct', 44)]
# ------------166
# [('12', 10), ('bitcoin', 10), ('0', 10), ('gt', 7), ('11', 6), ('1', 5), ('sell', 5)]
# ------------167
# [('bitcoin', 6), ('12', 3), ('cboe', 3), ('futur', 3), ('decemb', 2), ('price', 2), ('achiev', 2)]
# ------------168
# [('buy', 9), ('go', 7), ('100', 7), ('bitcoin', 6), ('order', 5), ('low', 4), ('mtgox', 4)]
# ------------169
# [('price', 86), ('bitcoin', 48), ('1', 27), ('1200', 24), ('time', 23), ('now', 19), ('exchang', 17)]
# ------------170
# [('price', 36), ('bitcoin', 34), ('think', 31), ('year', 31), ('decemb', 27), ('1200', 25), ('reach', 25)]
# ------------171
# [('bull', 28), ('bitcoin', 8), ('look', 8), ('fart', 8), ('extremecraft', 8), ('typepad', 8), ('6a00d8341bfe8453ef011571fefbee970b', 8)]
# ------------172
# [('bitcoin', 141), ('price', 112), ('happen', 61), ('just', 55), ('like', 50), ('year', 49), ('think', 47)]
# ------------173
# [('bitcoin', 18), ('back', 7), ('see', 7), ('just', 6), ('time', 6), ('peopl', 6), ('hit', 5)]
# ------------174
# [('bitcoin', 17), ('valu', 13), ('000', 8), ('1300', 6), ('say', 6), ('number', 5), ('get', 5)]
# ------------175
# [('bitcoin', 14), ('bank', 4), ('valu', 4), ('market', 4), ('hit', 4), ('target', 4), ('analysi', 3)]
# ------------176
# [('imgur', 2), ('5cpco', 2), ('bet', 1), ('can', 1), ('hit', 1), ('132', 1), ('end', 1)]
# ------------177
# [('bought', 3), ('price', 3), ('els', 2), ('say', 2), ('glad', 2), ('dip', 2), ('buy', 2)]
# ------------178
# [('price', 17), ('bitcoin', 14), ('peopl', 9), ('15', 8), ('now', 8), ('thread', 8), ('just', 7)]
# ------------179
# [('bitcoin', 13), ('price', 10), ('000', 6), ('next', 6), ('year', 6), ('look', 5), ('just', 5)]
# ------------180
# [('bitcoin', 29), ('can', 12), ('coin', 11), ('money', 11), ('buy', 9), ('just', 8), ('much', 8)]
# ------------181
# [('buy', 7), ('share', 6), ('just', 4), ('issuer', 4), ('reach', 3), ('wall', 3), ('sell', 3)]
# ------------182
# [('bitcoin', 13), ('150', 7), ('news', 6), ('go', 6), ('sell', 6), ('gox', 6), ('price', 6)]
# ------------183
# [('market', 11), ('see', 6), ('coin', 6), ('manipul', 6), ('trade', 5), ('volum', 5), ('price', 5)]
# ------------184
# [('price', 7), ('etf', 6), ('bitcoin', 5), ('correct', 5), ('reach', 4), ('around', 4), ('approv', 4)]
# ------------185
# [('bitcoin', 22), ('like', 17), ('bitfinex', 14), ('think', 13), ('price', 12), ('coin', 11), ('just', 11)]
# ------------186
# [('hit', 2), ('200', 2), ('pizza', 2), ('yay', 1), ('cmon', 1), ('peopl', 1), ('someth', 1)]
# ------------187
# [('bitcoin', 2), ('now', 2), ('game', 2), ('200', 1), ('198', 1), ('88bitcoin', 1), ('like', 1)]
# ------------188
# [('market', 5), ('cap', 5), ('2', 5), ('bitcoin', 5), ('80', 5), ('6', 3), ('billion', 3)]
# ------------189
# [('wall', 7), ('bitcoin', 6), ('price', 5), ('sold', 5), ('just', 4), ('know', 4), ('can', 4)]
# ------------190
# [('price', 147), ('bitcoin', 121), ('think', 76), ('halv', 63), ('reach', 55), ('happen', 54), ('go', 52)]
# ------------191
# [('1k', 5), ('ve', 3), ('tomorrow', 3), ('bitcoin', 3), ('watch', 2), ('gox', 2), ('go', 2)]
# ------------192
# [('think', 7), ('day', 7), ('just', 7), ('year', 6), ('go', 5), ('get', 5), ('peopl', 5)]
# ------------193
# [('price', 8), ('bitcoin', 6), ('dream', 4), ('now', 4), ('enjoy', 4), ('reach', 4), ('look', 3)]
# ------------194
# [('bitcoin', 28), ('price', 19), ('can', 17), ('gold', 17), ('good', 13), ('specul', 12), ('stabil', 11)]
# ------------195
# [('wave', 16), ('correct', 10), ('200', 10), ('just', 9), ('like', 9), ('happen', 7), ('time', 7)]
# ------------196
# [('bitcoin', 24), ('peopl', 16), ('price', 15), ('200', 14), ('go', 13), ('think', 12), ('buy', 11)]
# ------------197
# [('bitcoin', 183), ('price', 153), ('200', 67), ('happen', 63), ('think', 46), ('go', 37), ('now', 33)]
# ------------198
# [('bitcoin', 12), ('1', 9), ('200', 8), ('june', 5), ('end', 5), ('current', 4), ('rate', 4)]
# ------------199
# [('bitcoin', 292), ('price', 280), ('2000', 148), ('can', 95), ('now', 90), ('year', 89), ('see', 83)]
# ------------200
# [('bitcoin', 43), ('price', 34), ('see', 16), ('now', 12), ('hour', 9), ('next', 8), ('can', 7)]
# ------------201
# [('bitcoin', 24), ('year', 15), ('price', 14), ('go', 14), ('2000', 13), ('happen', 12), ('can', 11)]
# ------------202
# [('go', 2), ('get', 1), ('like', 1), ('auction', 1), ('eventu', 1), ('stop', 1), ('10', 1)]
# ------------203
# [('382', 3), ('coinmarketcap', 3), ('averag', 3), ('exchang', 3), ('360', 2), ('57', 2), ('two', 2)]
# ------------204
# [('bitcoin', 42), ('price', 36), ('now', 20), ('time', 17), ('rang', 16), ('see', 15), ('sell', 14)]
# ------------205
# [('price', 23), ('bitcoin', 23), ('go', 20), ('think', 11), ('buy', 10), ('200', 9), ('can', 8)]
# ------------206
# [('new', 7), ('now', 4), ('1', 3), ('declar', 2), ('floor', 2), ('bitcoin', 2), ('price', 2)]
# ------------207
# [('price', 19), ('go', 19), ('think', 13), ('see', 13), ('bitcoin', 11), ('happen', 11), ('peopl', 10)]
# ------------208
# [('price', 15), ('just', 10), ('see', 10), ('now', 9), ('usd', 8), ('bitcoin', 8), ('go', 7)]
# ------------209
# [('bitcoin', 4), ('panic', 4), ('recov', 4), ('recoveri', 4), ('sell', 4), ('just', 4), ('crash', 4)]
# ------------210
# [('bitcoin', 77), ('go', 38), ('can', 28), ('peopl', 24), ('just', 22), ('buy', 22), ('price', 22)]
# ------------211
# [('go', 4), ('like', 4), ('reach', 4), ('260', 4), ('think', 3), ('bitcoin', 3), ('logic', 3)]
# ------------212
# [('bitcoin', 6), ('dollar', 6), ('spike', 5), ('drop', 5), ('think', 4), ('look', 4), ('just', 4)]
# ------------213
# [('bitcoin', 5), ('happen', 5), ('price', 4), ('think', 4), ('can', 3), ('25', 2), ('predict', 2)]
# ------------214
# [('bitcoin', 73), ('think', 19), ('price', 17), ('good', 16), ('just', 15), ('can', 14), ('like', 13)]
# ------------215
# [('sell', 1), ('market', 1), ('depth', 1), ('small', 1), ('compar', 1), ('volum', 1), ('look', 1)]
# ------------216
# [('price', 263), ('bitcoin', 195), ('250', 100), ('go', 96), ('think', 82), ('now', 77), ('buy', 73)]
# ------------217
# [('250', 4), ('1000', 4), ('___', 4), ('now', 3), ('nice', 3), ('_', 3), ('look', 2)]
# ------------218
# [('one', 2), ('order', 2), ('anyon', 1), ('line', 1), ('credit', 1), ('wish', 1), ('extend', 1)]
# ------------219
# [('bid', 11), ('buy', 7), ('now', 7), ('bitcoin', 6), ('wall', 6), ('can', 6), ('money', 6)]
# ------------220
# [('bitcoin', 33), ('get', 14), ('price', 13), ('just', 12), ('think', 10), ('go', 10), ('can', 9)]
# ------------221
# [('bitcoin', 70), ('think', 40), ('now', 31), ('just', 29), ('price', 29), ('time', 26), ('like', 25)]
# ------------222
# [('price', 401), ('bitcoin', 236), ('think', 170), ('januari', 153), ('2k', 135), ('halv', 134), ('year', 128)]
# ------------223
# [('price', 12), ('bubbl', 8), ('just', 7), ('bitcoin', 6), ('time', 6), ('200', 6), ('180', 6)]
# ------------224
# [('bitcoin', 76), ('price', 59), ('3', 32), ('go', 29), ('dollar', 27), ('see', 26), ('sell', 25)]
# ------------225
# [('bitcoin', 79), ('price', 29), ('just', 23), ('one', 22), ('use', 20), ('market', 19), ('see', 17)]
# ------------226
# [('dl', 4), ('dropbox', 4), ('u', 4), ('72382452', 4), ('high', 4), ('last', 4), ('currenc', 4)]
# ------------227
# [('bitcoin', 7), ('bet', 6), ('wait', 4), ('bought', 4), ('now', 3), ('im', 3), ('thing', 3)]
# ------------228
# [('bitcoin', 15), ('price', 10), ('just', 7), ('14', 7), ('high', 6), ('org', 6), ('3', 5)]
# ------------229
# [('bitcoin', 11), ('see', 8), ('30', 7), ('price', 7), ('market', 7), ('think', 7), ('1', 7)]
# ------------230
# [('300', 35), ('bitcoin', 26), ('price', 23), ('just', 23), ('like', 20), ('think', 18), ('time', 15)]
# ------------231
# [('go', 2), ('will', 2), ('put', 2), ('money', 2), ('tire', 1), ('neg', 1), ('grain', 1)]
# ------------232
# [('line', 7), ('chart', 6), ('bullish', 6), ('sell', 6), ('kongzi', 5), ('ca', 5), ('silver', 5)]
# ------------233
# [('price', 116), ('bitcoin', 74), ('300', 66), ('can', 52), ('go', 43), ('end', 42), ('predict', 40)]
# ------------234
# [('imgur', 2), ('djlasir', 2), ('well', 2), ('sparta', 1), ('done', 1), ('sir', 1), ('donecan', 1)]
# ------------235
# [('price', 45), ('go', 39), ('bitcoin', 38), ('300', 34), ('800', 34), ('think', 32), ('see', 21)]
# ------------236
# [('300', 26), ('support', 9), ('bitcoin', 8), ('price', 8), ('level', 8), ('buy', 8), ('strong', 8)]
# ------------237
# [('order', 22), ('bitcoin', 18), ('think', 18), ('350', 17), ('buy', 16), ('just', 15), ('like', 15)]
# ------------238
# [('bitcoin', 17), ('price', 12), ('news', 7), ('china', 7), ('fork', 7), ('buy', 6), ('go', 6)]
# ------------239
# [('bitcoin', 97), ('price', 58), ('bu', 32), ('can', 25), ('think', 23), ('peopl', 22), ('see', 21)]
# ------------240
# [('price', 18), ('buy', 15), ('bitcoin', 13), ('low', 9), ('good', 9), ('see', 7), ('don', 7)]
# ------------241
# [('bitcoin', 64), ('hold', 26), ('now', 25), ('sell', 22), ('price', 21), ('money', 17), ('just', 16)]
# ------------242
# [('bitcoin', 30), ('price', 19), ('think', 12), ('don', 11), ('xt', 9), ('300', 8), ('see', 7)]
# ------------243
# [('bitcoin', 24), ('price', 17), ('time', 10), ('go', 10), ('now', 9), ('reason', 8), ('rise', 8)]
# ------------244
# [('35', 19), ('go', 18), ('price', 18), ('like', 17), ('bitcoin', 16), ('think', 14), ('100', 13)]
# ------------245
# [('sunday', 37), ('300', 35), ('bitcoin', 34), ('350', 32), ('price', 27), ('now', 24), ('see', 22)]
# ------------246
# [('think', 17), ('300', 15), ('level', 13), ('just', 13), ('break', 13), ('market', 13), ('bitcoin', 13)]
# ------------247
# [('price', 93), ('bitcoin', 57), ('350', 49), ('barrier', 41), ('now', 37), ('think', 32), ('go', 30)]
# ------------248
# [('350', 10), ('think', 8), ('just', 7), ('bitcoin', 6), ('see', 5), ('week', 5), ('like', 5)]
# ------------249
# [('price', 243), ('bitcoin', 141), ('350', 121), ('think', 111), ('go', 111), ('bottom', 105), ('can', 97)]
# ------------250
# [('price', 13), ('300', 12), ('can', 11), ('think', 11), ('see', 11), ('bitcoin', 10), ('week', 9)]
# ------------251
# [('bitcoin', 12), ('gold', 11), ('give', 4), ('rate', 3), ('price', 3), ('use', 3), ('us', 3)]
# ------------252
# [('bitcoin', 54), ('price', 50), ('now', 28), ('just', 22), ('can', 21), ('3500', 20), ('see', 19)]
# ------------253
# [('comment', 6), ('ponzi', 6), ('bitcoin', 6), ('know', 5), ('reddit', 4), ('price', 4), ('time', 4)]
# ------------254
# [('price', 28), ('bitcoin', 22), ('go', 14), ('hold', 11), ('can', 9), ('time', 8), ('now', 8)]
# ------------255
# [('bitcoin', 15), ('4', 10), ('can', 8), ('good', 7), ('agre', 7), ('now', 7), ('affluent', 7)]
# ------------256
# [('4', 11), ('correct', 10), ('just', 8), ('see', 7), ('5', 6), ('time', 6), ('like', 6)]
# ------------257
# [('bitcoin', 59), ('price', 31), ('4000', 19), ('see', 17), ('now', 17), ('go', 16), ('us', 11)]
# ------------258
# [('size', 5), ('import', 5), ('line', 5), ('height', 5), ('1', 5), ('3em', 5), ('buy', 5)]
# ------------259
# [('free', 1), ('rise', 1)]
# ------------260
# [('400', 10), ('bitcoin', 9), ('now', 8), ('say', 6), ('happen', 5), ('guess', 5), ('see', 5)]
# ------------261
# [('go', 11), ('like', 8), ('time', 8), ('help', 8), ('look', 7), ('now', 6), ('think', 6)]
# ------------262
# [('thank', 2), ('peopl', 1), ('held', 1), ('strong', 1), ('time', 1), ('uncertainti', 1), ('know', 1)]
# ------------263
# [('know', 2), ('hold', 2), ('want', 2), ('18', 2), ('month', 2), ('say', 2), ('knowledg', 2)]
# ------------264
# [('price', 180), ('400', 99), ('bitcoin', 90), ('go', 80), ('weekend', 47), ('think', 46), ('see', 45)]
# ------------265
# [('400', 51), ('price', 45), ('bitcoin', 41), ('think', 29), ('reach', 22), ('go', 19), ('just', 17)]
# ------------266
# [('postimg', 6), ('org', 6), ('go', 4), ('get', 4), ('price', 3), ('correct', 3), ('oh', 3)]
# ------------267
# [('max', 2), ('still', 1), ('want', 1), ('lose', 1), ('money', 1), ('keep', 1), ('hold', 1)]
# ------------268
# [('bitcoin', 38), ('money', 29), ('peopl', 26), ('sell', 22), ('go', 21), ('lose', 19), ('just', 17)]
# ------------269
# [('bitcoin', 25), ('price', 14), ('buy', 10), ('coin', 10), ('like', 9), ('get', 9), ('can', 9)]
# ------------270
# [('bitcoin', 26), ('can', 9), ('go', 7), ('real', 6), ('time', 6), ('paypal', 6), ('peopl', 6)]
# ------------271
# [('price', 28), ('go', 12), ('can', 10), ('profit', 8), ('time', 8), ('see', 8), ('pump', 7)]
# ------------272
# [('price', 21), ('500', 15), ('bitcoin', 11), ('month', 10), ('may', 10), ('much', 9), ('halv', 8)]
# ------------273
# [('bitcoin', 68), ('price', 27), ('buy', 21), ('money', 21), ('sell', 20), ('just', 19), ('china', 18)]
# ------------274
# [('bubbl', 8), ('day', 6), ('think', 6), ('guess', 4), ('7', 4), ('next', 4), ('just', 4)]
# ------------275
# [('price', 103), ('bitcoin', 62), ('now', 34), ('go', 30), ('time', 29), ('peopl', 28), ('rise', 27)]
# ------------276
# [('2012', 41), ('use', 23), ('2011', 22), ('date', 21), ('1', 21), ('format', 20), ('time', 18)]
# ------------277
# [('bitcoin', 13), ('us', 6), ('imageshack', 5), ('right', 5), ('now', 5), ('accept', 5), ('let', 4)]
# ------------278
# [('i41', 2), ('tinyp', 2), ('ix5c0k', 2), ('just', 1), ('notic', 1)]
# ------------279
# [('5', 13), ('4', 10), ('go', 10), ('think', 10), ('now', 8), ('back', 7), ('see', 6)]
# ------------280
# [('bitcoin', 25), ('price', 22), ('correct', 10), ('fork', 8), ('get', 8), ('increas', 7), ('still', 7)]
# ------------281
# [('5', 4), ('back', 4), ('look', 3), ('price', 3), ('bitcoin', 3), ('articl', 3), ('bullish', 2)]
# ------------282
# [('5', 23), ('bitcoin', 12), ('0', 12), ('go', 11), ('keep', 11), ('see', 10), ('6', 10)]
# ------------283
# [('like', 3), ('can', 2), ('currenc', 2), ('serious', 1), ('glad', 1), ('sold', 1), ('rest', 1)]
# ------------284
# [('price', 8), ('know', 7), ('happen', 7), ('time', 7), ('just', 6), ('drop', 6), ('bitcoin', 6)]
# ------------285
# [('price', 238), ('500', 173), ('bitcoin', 163), ('month', 153), ('halv', 122), ('think', 101), ('now', 80)]
# ------------286
# [('price', 132), ('500', 90), ('bitcoin', 89), ('may', 79), ('think', 61), ('can', 46), ('reach', 43)]
# ------------287
# [('christma', 10), ('think', 7), ('bitcoin', 7), ('500', 5), ('poll', 4), ('day', 4), ('seem', 4)]
# ------------288
# [('bitcoin', 43), ('price', 23), ('500', 15), ('like', 14), ('just', 14), ('money', 12), ('market', 12)]
# ------------289
# [('dollar', 5), ('year', 4), ('inflat', 4), ('new', 3), ('50', 3), ('can', 3), ('truth', 3)]
# ------------290
# [('bitcoin', 434), ('price', 145), ('000', 93), ('can', 89), ('year', 89), ('power', 88), ('think', 86)]
# ------------291
# [('bitcoin', 133), ('price', 113), ('now', 49), ('can', 43), ('time', 40), ('see', 34), ('reach', 32)]
# ------------292
# [('bitcoin', 152), ('price', 108), ('5000', 58), ('now', 43), ('reach', 37), ('can', 32), ('year', 32)]
# ------------293
# [('9617', 836), ('9608', 482), ('9604', 344), ('9600', 336), ('bitcoin', 252), ('9612', 202), ('9616', 202)]
# ------------294
# [('bitcoin', 48), ('price', 22), ('year', 14), ('think', 11), ('possibl', 9), ('peopl', 9), ('know', 9)]
# ------------295
# [('bitcoin', 10), ('price', 10), ('50k', 9), ('tether', 5), ('2', 5), ('market', 5), ('year', 5)]
# ------------296
# [('buy', 11), ('price', 9), ('market', 8), ('bitcoin', 8), ('now', 8), ('china', 7), ('news', 7)]
# ------------297
# [('get', 1), ('board', 1), ('china', 1), ('devalu', 1), ('currenc', 1), ('least', 1), ('15', 1)]
# ------------298
# [('price', 10), ('think', 9), ('bitcoin', 7), ('now', 5), ('good', 5), ('600', 5), ('manipul', 5)]
# ------------299
# [('bitcoin', 9), ('get', 7), ('china', 6), ('price', 5), ('can', 5), ('rmb', 4), ('exchang', 4)]
# ------------300
# [('bitcoin', 15), ('fork', 9), ('core', 8), ('blockstream', 8), ('price', 7), ('55', 5), ('dev', 5)]
# ------------301
# [('sell', 4), ('just', 3), ('buy', 3), ('bitcoin', 3), ('ridicul', 2), ('back', 2), ('friday', 2)]
# ------------302
# [('halv', 12), ('think', 11), ('dump', 10), ('price', 10), ('bitcoin', 8), ('see', 7), ('block', 6)]
# ------------303
# [('price', 25), ('bitcoin', 21), ('just', 20), ('buy', 14), ('can', 14), ('troll', 13), ('see', 12)]
# ------------304
# [('bitcoin', 11), ('price', 10), ('just', 8), ('buy', 7), ('go', 7), ('realli', 5), ('sell', 5)]
# ------------305
# [('look', 7), ('happen', 5), ('go', 5), ('don', 4), ('chart', 4), ('blow', 4), ('just', 3)]
# ------------306
# [('bitcoin', 27), ('6', 25), ('see', 21), ('now', 20), ('5', 19), ('go', 15), ('can', 13)]
# ------------307
# [('6', 5), ('resist', 3), ('now', 3), ('empti', 2), ('chart', 2), ('technic', 2), ('provid', 2)]
# ------------308
# [('bitcoin', 13), ('surpris', 8), ('like', 7), ('one', 6), ('buy', 6), ('back', 6), ('post', 6)]
# ------------309
# [('now', 5), ('chines', 4), ('bitcoin', 4), ('look', 3), ('600', 3), ('bubbl', 3), ('bear', 3)]
# ------------310
# [('bitcoin', 11), ('price', 10), ('rise', 10), ('think', 10), ('buy', 9), ('need', 8), ('market', 7)]
# ------------311
# [('600', 27), ('price', 23), ('today', 17), ('reach', 14), ('see', 12), ('think', 10), ('time', 10)]
# ------------312
# [('bitcoin', 20), ('coin', 9), ('miner', 8), ('think', 8), ('go', 7), ('mayb', 7), ('money', 7)]
# ------------313
# [('bitcoin', 187), ('price', 138), ('fork', 57), ('6000', 54), ('see', 44), ('happen', 41), ('reach', 40)]
# ------------314
# [('back', 8), ('time', 7), ('price', 6), ('hack', 4), ('panic', 4), ('now', 3), ('bitcoin', 3)]
# ------------315
# [('bitcoin', 11), ('buy', 10), ('time', 6), ('price', 5), ('back', 5), ('see', 5), ('probabl', 5)]
# ------------316
# [('buy', 68), ('price', 65), ('bitcoin', 57), ('now', 43), ('good', 41), ('time', 28), ('go', 27)]
# ------------317
# [('bitcoin', 33), ('price', 20), ('buy', 18), ('think', 17), ('good', 13), ('just', 12), ('coin', 12)]
# ------------318
# [('soon', 3), ('sell', 3), ('65', 3), ('back', 3), ('even', 3), ('price', 3), ('come', 2)]
# ------------319
# [('bitcoin', 30), ('price', 16), ('year', 13), ('usd', 12), ('buy', 11), ('invest', 11), ('rich', 10)]
# ------------320
# [('price', 36), ('bitcoin', 29), ('halv', 21), ('go', 12), ('buy', 11), ('can', 10), ('increas', 10)]
# ------------321
# [('halv', 10), ('price', 9), ('bitcoin', 7), ('now', 6), ('day', 6), ('like', 5), ('just', 5)]
# ------------322
# [('look', 3), ('think', 3), ('go', 2), ('stabl', 2), ('now', 2), ('weekend', 2), ('can', 2)]
# ------------323
# [('price', 29), ('bitcoinica', 24), ('2', 20), ('short', 17), ('buy', 12), ('1', 11), ('7', 10)]
# ------------324
# [('6', 15), ('7', 12), ('now', 10), ('5', 9), ('correct', 9), ('just', 8), ('1', 7)]
# ------------325
# [('bitcoin', 86), ('bank', 54), ('peopl', 32), ('can', 29), ('get', 24), ('transact', 23), ('go', 21)]
# ------------326
# [('bitcoin', 8), ('bid', 2), ('price', 2), ('opposit', 2), ('segwit2x', 2), ('blockchain', 2), ('creat', 2)]
# ------------327
# [('rate', 2), ('largest', 2), ('someth', 2), ('worth', 2), ('rise', 2), ('90', 2), ('hollywoodreport', 2)]
# ------------328
# [('new', 3), ('100', 2), ('someon', 1), ('say', 1), ('120', 1), ('still', 1), ('dand', 1)]
# ------------329
# [('bitcoin', 19), ('buy', 12), ('68', 9), ('go', 9), ('time', 8), ('hour', 8), ('70', 7)]
# ------------330
# [('bitcoin', 115), ('year', 74), ('price', 67), ('000', 56), ('can', 40), ('reach', 35), ('happen', 31)]
# ------------331
# [('price', 190), ('bitcoin', 135), ('year', 88), ('800', 62), ('700', 54), ('reach', 53), ('see', 53)]
# ------------332
# [('price', 38), ('700', 21), ('go', 18), ('day', 17), ('bitcoin', 16), ('can', 15), ('week', 13)]
# ------------333
# [('price', 123), ('bitcoin', 67), ('halv', 47), ('700', 34), ('think', 33), ('can', 24), ('just', 22)]
# ------------334
# [('bitcoin', 62), ('go', 19), ('just', 19), ('market', 17), ('price', 16), ('trap', 13), ('peopl', 12)]
# ------------335
# [('000', 11), ('store', 4), ('picbg', 4), ('net', 4), ('pubpic', 4), ('2d', 2), ('70', 2)]
# ------------336
# [('75', 8), ('go', 4), ('betsofbitco', 4), ('item', 4), ('id', 4), ('price', 3), ('usd', 3)]
# ------------337
# [('wall', 5), ('today', 4), ('chanc', 3), ('well', 3), ('75', 3), ('get', 3), ('tomorrow', 2)]
# ------------338
# [('bitcoin', 11), ('price', 9), ('7500', 6), ('believ', 5), ('resist', 5), ('2018', 5), ('fork', 5)]
# ------------339
# [('24', 2), ('hr', 2), ('get', 2), ('just', 2), ('day', 2), ('newsimg', 2), ('bbc', 2)]
# ------------340
# [('bitcoin', 11), ('can', 5), ('just', 4), ('trade', 4), ('2', 4), ('recent', 4), ('price', 4)]
# ------------341
# [('watch', 4), ('http', 2), ('youtub', 2), ('v', 2), ('lol', 2), ('like', 2), ('0afxxaobuq8hahahah', 1)]
# ------------342
# [('dump', 4), ('watch', 3), ('see', 3), ('like', 3), ('wall', 3), ('lol', 3), ('max', 3)]
# ------------343
# [('bitstamp', 9), ('bitcoin', 9), ('buy', 5), ('now', 5), ('gox', 4), ('shrani', 4), ('si', 4)]
# ------------344
# [('like', 7), ('price', 7), ('800', 7), ('new', 6), ('bitcoin', 6), ('1', 5), ('day', 4)]
# ------------345
# [('800', 22), ('price', 18), ('see', 14), ('now', 9), ('1000', 9), ('day', 9), ('tomorrow', 8)]
# ------------346
# [('bitcoin', 31), ('now', 18), ('price', 17), ('just', 14), ('buy', 14), ('see', 13), ('market', 13)]
# ------------347
# [('bitcoin', 31), ('trade', 17), ('whale', 16), ('market', 15), ('think', 15), ('much', 15), ('go', 14)]
# ------------348
# [('price', 34), ('now', 24), ('bitcoin', 19), ('market', 19), ('can', 17), ('realli', 14), ('think', 13)]
# ------------349
# [('googl', 4), ('trend', 4), ('bitcoin', 4), ('price', 4), ('interest', 2), ('level', 2), ('90', 2)]
# ------------350
# [('i3', 2), ('kym', 2), ('cdn', 2), ('entri', 2), ('icon', 2), ('origin', 2), ('000', 2)]
# ------------351
# [('100', 9), ('think', 4), ('last', 3), ('big', 3), ('see', 3), ('just', 3), ('much', 3)]
# ------------352
# [('1k', 2), ('hit', 2), ('feel', 1), ('bone', 1), ('danc', 1), ('readi', 1), ('drop', 1)]
# ------------353
# [('news', 5), ('bitcoin', 3), ('money', 3), ('peopl', 3), ('today', 2), ('cnn', 2), ('media', 2)]
# ------------354
# [('bitcoin', 17), ('price', 17), ('us', 11), ('imag', 10), ('imageshack', 10), ('now', 9), ('market', 7)]
# ------------355
# [('price', 22), ('bitcoin', 21), ('market', 13), ('now', 11), ('long', 10), ('time', 10), ('go', 9)]
# ------------356
# [('market', 7), ('indic', 7), ('term', 6), ('near', 5), ('chart', 4), ('need', 4), ('think', 4)]
# ------------357
# [('can', 6), ('still', 5), ('price', 5), ('move', 5), ('think', 5), ('volum', 5), ('bitcoin', 4)]
# ------------358
# [('protrad', 7), ('close', 7), ('long', 6), ('level', 6), ('term', 5), ('market', 5), ('area', 5)]
# ------------359
# [('price', 16), ('bitcoin', 14), ('700', 10), ('think', 8), ('still', 6), ('support', 6), ('level', 6)]
# ------------360
# [('bitcoin', 3), ('5', 3), ('1', 2), ('opinion', 2), ('back', 1), ('2011', 1), ('piec', 1)]
# ------------361
# [('00', 201), ('bitcoin', 129), ('50', 110), ('gbtc', 107), ('price', 95), ('market', 85), ('share', 81)]
# ------------362
# [('2010', 8), ('rate', 7), ('bitcoin', 5), ('2009', 4), ('usd', 4), ('0', 4), ('newlibertystandard', 4)]
# ------------363
# [('bitcoin', 28), ('world', 17), ('pop', 14), ('peak', 10), ('bubbl', 10), ('year', 9), ('support', 9)]
# ------------364
# [('bitcoin', 22), ('atm', 11), ('australia', 8), ('good', 7), ('time', 7), ('go', 6), ('like', 6)]
# ------------365
# [('use', 7), ('like', 6), ('bitcoin', 5), ('one', 5), ('analysi', 4), ('read', 4), ('good', 4)]
# ------------366
# [('bitcoin', 39), ('parabol', 16), ('now', 16), ('go', 14), ('can', 12), ('look', 11), ('price', 11)]
# ------------367
# [('need', 1), ('say', 1)]
# ------------368
# [('rope', 2), ('nanday', 1), ('day', 1), ('ok', 1), ('question', 1), ('remain', 1), ('mark', 1)]
# ------------369
# [('bitcoin', 75), ('bubbl', 20), ('like', 18), ('price', 18), ('money', 11), ('can', 11), ('buy', 11)]
# ------------370
# [('bitcoin', 18), ('price', 18), ('100', 17), ('day', 12), ('miner', 11), ('term', 9), ('buy', 7)]
# ------------371
# [('wall', 7), ('market', 5), ('bitcoin', 5), ('21', 4), ('dump', 4), ('buy', 3), ('watch', 3)]
# ------------372
# [('price', 78), ('bitcoin', 63), ('year', 34), ('see', 31), ('now', 29), ('can', 27), ('think', 27)]
# ------------373
# [('price', 34), ('year', 29), ('bitcoin', 27), ('go', 23), ('sell', 20), ('now', 20), ('don', 20)]
# ------------374
# [('strike', 10), ('option', 10), ('bitcoin', 10), ('price', 6), ('50', 4), ('market', 4), ('month', 4)]
# ------------375
# [('gox', 47), ('bitcoin', 31), ('can', 18), ('money', 17), ('just', 16), ('coin', 13), ('buy', 10)]
# ------------376
# [('bitcoin', 21), ('gox', 16), ('0', 12), ('buy', 12), ('go', 11), ('now', 10), ('price', 9)]
# ------------377
# [('bitcoin', 10), ('market', 7), ('cap', 7), ('imgur', 4), ('week', 4), ('http', 3), ('price', 3)]
# ------------378
# [('now', 18), ('buy', 15), ('price', 14), ('time', 13), ('bitcoin', 13), ('long', 13), ('term', 13)]
# ------------379
# [('http', 2), ('reddit', 2), ('r', 2), ('bitcoin', 2), ('comment', 2), ('3rgc62', 2), ('_', 2)]
# ------------380
# [('bitcoinica', 24), ('reserv', 17), ('peopl', 15), ('liquid', 13), ('bitcoin', 13), ('squeez', 11), ('starfish', 10)]
# ------------381
# [('bitcoin', 20), ('peopl', 11), ('3', 6), ('reason', 6), ('know', 6), ('drug', 6), ('crisi', 6)]
# ------------382
# [('see', 1), ('bloomberg', 1), ('news', 1), ('2014', 1), ('03', 1), ('27', 1), ('pboc', 1)]
# ------------383
# [('predict', 2), ('forecast', 2), ('bitcoin', 2), ('economi', 1), ('agenc', 1), ('special', 1), ('long', 1)]
# ------------384
# [('bitcoin', 16), ('imgur', 8), ('day', 8), ('go', 7), ('buy', 7), ('short', 7), ('1', 6)]
# ------------385
# [('banker', 8), ('leonida', 7), ('king', 7), ('sparta', 3), ('greek', 2), ('word', 2), ('care', 2)]
# ------------386
# [('bitcoin', 13), ('sell', 11), ('don', 10), ('now', 10), ('buy', 10), ('bubbl', 9), ('time', 9)]
# ------------387
# [('postimg', 4), ('org', 4), ('s7', 2), ('6dmcjcq8r', 2), ('gawk', 2), ('s24', 2), ('w2oxm6h1x', 2)]
# ------------388
# [('bitcoin', 49), ('think', 13), ('peopl', 13), ('still', 12), ('bubbl', 11), ('time', 11), ('thing', 10)]
# ------------389
# [('bitcoin', 11), ('sell', 9), ('price', 8), ('now', 7), ('hold', 7), ('go', 7), ('peopl', 6)]
# ------------390
# [('imgur', 2), ('h0ynreil', 2), ('marti', 1), ('mcfaillll', 1), ('delorean', 1), ('broke', 1), ('2011', 1)]
# ------------391
# [('bitcoin', 12), ('amazon', 5), ('coin', 4), ('got', 3), ('soon', 3), ('don', 3), ('far', 2)]
# ------------392
# [('price', 176), ('bitcoin', 103), ('go', 41), ('now', 41), ('rise', 40), ('think', 38), ('can', 36)]
# ------------393
# [('bitcoin', 22), ('rise', 11), ('see', 9), ('now', 9), ('hold', 9), ('price', 9), ('year', 8)]
# ------------394
# [('work', 7), ('freeimagehost', 6), ('net', 6), ('btcchart', 6), ('just', 5), ('mtgoxliv', 5), ('usd', 4)]
# ------------395
# [('bitcoin', 27), ('can', 15), ('price', 13), ('money', 12), ('year', 11), ('time', 10), ('month', 9)]
# ------------396
# [('bitcoin', 24), ('price', 22), ('buy', 14), ('market', 11), ('like', 8), ('worth', 8), ('order', 8)]
# ------------397
# [('bitcoin', 21), ('think', 18), ('price', 18), ('go', 16), ('bear', 13), ('0', 10), ('buy', 9)]
# ------------398
# [('7', 13), ('wall', 10), ('one', 10), ('vote', 7), ('imageshack', 6), ('us', 6), ('mayb', 6)]
# ------------399
# [('bitcoin', 799), ('price', 448), ('can', 297), ('market', 260), ('just', 249), ('like', 227), ('buy', 220)]
# ------------400
# [('bitcoin', 28), ('crypto', 9), ('alt', 9), ('fiat', 8), ('trade', 8), ('imgur', 8), ('exchang', 6)]
# ------------401
# [('bitcoin', 597), ('price', 273), ('buy', 211), ('just', 190), ('peopl', 182), ('go', 180), ('can', 161)]
# ------------402
# [('pump', 5), ('support', 5), ('go', 5), ('price', 4), ('bitcoin', 4), ('readi', 3), ('get', 3)]
# ------------403
# [('bitcoin', 129), ('go', 46), ('just', 43), ('govern', 36), ('time', 33), ('can', 32), ('get', 31)]
# ------------404
# [('bitcoin', 8), ('go', 6), ('gox', 6), ('way', 5), ('coin', 5), ('dump', 4), ('just', 4)]
# ------------405
# [('price', 35), ('bitcoin', 31), ('peopl', 19), ('sell', 15), ('go', 14), ('even', 13), ('think', 12)]
# ------------406
# [('deadlin', 5), ('separ', 5), ('forc', 4), ('enforc', 4), ('like', 3), ('10th', 3), ('may', 3)]
# ------------407
# [('bubbl', 16), ('happen', 14), ('price', 14), ('market', 13), ('bitcoin', 10), ('dip', 8), ('just', 7)]
# ------------408
# [('bitcoin', 8), ('just', 7), ('good', 6), ('go', 6), ('price', 6), ('buy', 6), ('think', 5)]
# ------------409
# [('bitcoin', 8), ('like', 4), ('exchang', 4), ('peopl', 2), ('least', 2), ('look', 2), ('french', 2)]
# ------------410
# [('price', 78), ('00', 76), ('predict', 68), ('bitcoin', 48), ('june', 38), ('guess', 31), ('go', 26)]
# ------------411
# [('predict', 83), ('price', 79), ('bitcoin', 49), ('juli', 46), ('guess', 43), ('1', 39), ('halv', 37)]
# ------------412
# [('bitcoin', 52), ('price', 38), ('go', 23), ('can', 21), ('10k', 16), ('year', 16), ('new', 15)]
# ------------413
# [('bitcoin', 9), ('price', 8), ('mine', 6), ('market', 5), ('news', 5), ('china', 5), ('go', 4)]
# ------------414
# [('bitcoin', 35), ('price', 31), ('think', 23), ('now', 22), ('market', 21), ('go', 19), ('wait', 19)]
# ------------415
# [('1buy', 1), ('train', 1), ('leav', 1)]
# ------------416
# [('100', 14), ('bitcoin', 12), ('think', 11), ('buy', 7), ('sell', 6), ('crash', 6), ('usd', 5)]
# ------------417
# ...
# ------------963
# [('currenc', 5), ('virtual', 4), ('bitcoin', 3), ('inc', 3), ('bank', 3), ('press', 3), ('wsj', 2)]
# ------------964
# [('bitcoinica', 71), ('market', 41), ('can', 38), ('trade', 37), ('data', 29), ('use', 27), ('don', 27)]
# ------------965
# [('bitcoin', 28), ('buy', 26), ('price', 25), ('now', 14), ('dip', 14), ('peopl', 13), ('1000', 13)]
# ------------966
# [('bitcoin', 35), ('one', 10), ('get', 8), ('peopl', 7), ('just', 7), ('price', 6), ('1', 6)]
# ------------967
# [('bitcoinica', 20), ('price', 11), ('mtgox', 11), ('leverag', 9), ('money', 9), ('bitcoin', 9), ('close', 8)]
# ------------968
# [('bitcoin', 29), ('sustain', 25), ('time', 13), ('year', 13), ('invest', 10), ('protocol', 8), ('trade', 8)]
# ------------969
# [('bitcoin', 14), ('coin', 12), ('can', 8), ('1', 8), ('usd', 7), ('suppli', 6), ('just', 6)]
# ------------970
# [('etf', 23), ('bitcoin', 21), ('price', 20), ('think', 10), ('solidx', 10), ('go', 10), ('peopl', 9)]
# ------------971
# [('bitcoin', 30), ('price', 28), ('buy', 27), ('time', 21), ('can', 17), ('see', 14), ('market', 14)]
# ------------972
# [('000', 21), ('day', 14), ('halv', 12), ('coin', 11), ('per', 10), ('market', 9), ('cap', 9)]
# ------------973
# [('bitcoin', 15), ('china', 8), ('day', 8), ('blah', 7), ('exchang', 6), ('also', 6), ('go', 6)]
# ------------974
# [('inherit', 92), ('td', 88), ('color', 46), ('top', 45), ('valign', 44), ('price', 28), ('halv', 25)]
# ------------975
# [('bitcoin', 26), ('back', 26), ('valu', 12), ('trust', 9), ('can', 9), ('price', 9), ('peopl', 9)]
# ------------976
# [('market', 3), ('good', 3), ('point', 3), ('analisi', 3), ('perhap', 3), ('sociologist', 3), ('everi', 2)]
# ------------977
# [('bitcoin', 23), ('halv', 22), ('coin', 21), ('mine', 17), ('price', 14), ('think', 9), ('bubbl', 8)]
# ------------978
# [('bitcoin', 17), ('1000', 13), ('parti', 13), ('celebr', 8), ('1', 7), ('sell', 5), ('price', 5)]
# ------------979
# [('us', 2), ('think', 1), ('doesn', 1), ('charg', 1), ('nonresid', 1), ('alien', 1), ('use', 1)]
# ------------980
# [('bitcoin', 260), ('price', 109), ('august', 86), ('go', 58), ('1', 57), ('happen', 54), ('now', 42)]
# ------------981
# [('trade', 48), ('margin', 26), ('bitcoin', 19), ('take', 13), ('use', 12), ('just', 12), ('can', 12)]
# ------------982
# [('good', 6), ('bitcoin', 6), ('hype', 6), ('analysi', 4), ('price', 4), ('high', 4), ('level', 4)]
# ------------983
# [('bitcoin', 18), ('buy', 13), ('term', 8), ('price', 7), ('now', 7), ('long', 7), ('still', 7)]
# ------------984
# [('channel', 16), ('imgur', 15), ('point', 13), ('re', 12), ('now', 12), ('see', 11), ('support', 10)]
# ------------985
# [('bitcoin', 7), ('famili', 4), ('ransom', 4), ('news', 4), ('confirm', 3), ('kidnapp', 3), ('cointelegraph', 3)]
# ------------986
# [('volum', 2), ('anyon', 1), ('know', 1), ('fund', 1), ('full', 1), ('depth', 1), ('chart', 1)]
# ------------987
# [('crypto', 4), ('now', 3), ('1', 3), ('wealth', 2), ('tie', 2), ('bitcoin', 2), ('place', 2)]
# ------------988
# [('just', 2), ('bitcoin', 2), ('parallel', 2), ('msg904055', 2), ('curiou', 1), ('everybodi', 1), ('thought', 1)]
# ------------989
# [('post', 2), ('interest', 1), ('see', 1), ('get', 1), ('fill', 1), ('300', 1), ('appar', 1)]
# ------------990
# [('bitcoin', 7), ('manipul', 7), ('right', 6), ('market', 6), ('now', 6), ('get', 5), ('just', 5)]
# ------------991
# [('bitcoin', 16), ('impact', 14), ('war', 13), ('don', 12), ('price', 11), ('turkey', 11), ('russia', 10)]
# ------------992
# [('bitcoin', 58), ('trade', 37), ('buy', 22), ('sell', 20), ('go', 20), ('just', 19), ('make', 19)]
# ------------993
# [('etf', 13), ('bitcoin', 8), ('news', 8), ('come', 6), ('imgur', 6), ('make', 6), ('happen', 5)]
# ------------994
# [('pattern', 5), ('time', 5), ('price', 4), ('goe', 4), ('china', 3), ('alreadi', 3), ('sun', 3)]
# ------------995
# [('price', 15), ('3', 13), ('sell', 9), ('order', 7), ('bitcoin', 6), ('like', 6), ('buy', 5)]
# ------------996
# [('bitcoin', 28), ('can', 10), ('peopl', 5), ('don', 5), ('want', 5), ('pitch', 5), ('problem', 5)]
# ------------997
# [('bitcoin', 22), ('just', 5), ('good', 5), ('peopl', 5), ('someon', 4), ('somehow', 4), ('stolen', 4)]
# ------------998
# [('price', 6), ('bitcoin', 3), ('predict', 2), ('2018', 2), ('februari', 2), ('month', 2), ('feb', 1)]
# ------------999
# [('bitcoin', 44), ('can', 22), ('price', 18), ('predict', 17), ('market', 12), ('year', 12), ('one', 11)]
# ------------1000
# [('hear', 2), ('technic', 2), ('analysi', 2), ('stock', 2), ('know', 2), ('think', 2), ('watch', 1)]
# ------------1001
# [('bitcoin', 31), ('day', 21), ('peopl', 19), ('hodl', 16), ('hold', 11), ('want', 10), ('think', 9)]
# ------------1002
# [('price', 19), ('bitcoin', 19), ('market', 10), ('get', 9), ('dump', 8), ('peopl', 8), ('happen', 7)]
# ------------1003
# [('bitcoin', 20), ('price', 12), ('news', 8), ('caus', 7), ('just', 6), ('think', 6), ('specul', 5)]
# ------------1004
# [('bitcoin', 6), ('buy', 6), ('day', 3), ('lot', 3), ('peopl', 3), ('also', 3), ('go', 3)]
# ------------1005
# [('hype', 8), ('bitcoin', 7), ('correct', 6), ('happen', 6), ('just', 5), ('price', 5), ('50', 5)]
# ------------1006
# [('specul', 2), ('fli', 2), ('ve', 1), ('incognito', 1), ('sinc', 1), ('san', 1), ('jose', 1)]
# ------------1007
# [('coindesk', 6), ('price', 6), ('435', 5), ('seem', 3), ('show', 3), ('bitcoin', 3), ('doesn', 2)]
# ------------1008
# [('2', 27), ('3', 20), ('go', 11), ('bitcoin', 11), ('5', 9), ('think', 8), ('can', 7)]
# ------------1009
# [('price', 55), ('bitcoin', 32), ('correct', 17), ('just', 16), ('happen', 11), ('drop', 10), ('can', 10)]
# ------------1010
# [('trade', 17), ('rsi', 17), ('indic', 14), ('use', 12), ('can', 11), ('overbought', 11), ('get', 10)]
# ------------1011
# [('peopl', 24), ('bitcoin', 24), ('go', 23), ('just', 20), ('now', 16), ('gox', 16), ('price', 14)]
# ------------1012
# [('mine', 49), ('bitcoin', 44), ('price', 38), ('cost', 34), ('electr', 30), ('miner', 24), ('1', 21)]
# ------------1013
# [('price', 21), ('gox', 18), ('even', 16), ('bitcoin', 15), ('bot', 13), ('know', 12), ('time', 10)]
# ------------1014
# [('bitcoin', 32), ('short', 29), ('go', 11), ('think', 10), ('imgflip', 10), ('good', 8), ('price', 8)]
# ------------1015
# [('gox', 17), ('bitcoin', 12), ('withdraw', 8), ('coin', 6), ('josh', 6), ('just', 5), ('goxbtc', 5)]
# ------------1016
# [('bitcoin', 63), ('time', 18), ('like', 18), ('just', 17), ('buy', 16), ('year', 16), ('invest', 15)]
# ------------1017
# [('bitcoin', 31), ('price', 26), ('lend', 25), ('market', 16), ('interest', 15), ('peopl', 15), ('sell', 15)]
# ------------1018
# [('price', 11), ('bitcoin', 8), ('sell', 5), ('660', 4), ('drop', 3), ('trade', 3), ('see', 3)]
# ------------1019
# [('price', 8), ('bitcoin', 6), ('peopl', 4), ('stabl', 4), ('100', 3), ('stabil', 3), ('spend', 3)]
# ------------1020
# [('price', 50), ('bitcoin', 29), ('buy', 25), ('bought', 17), ('go', 15), ('now', 13), ('wait', 12)]
# ------------1021
# [('panick', 4), ('step', 2), ('seller', 2), ('sold', 2), ('buyer', 2), ('bought', 2), ('mean', 1)]
# ------------1022
# [('bitcoin', 8), ('price', 4), ('ethereum', 3), ('analysi', 3), ('2016', 3), ('03', 3), ('point', 3)]
# ------------1023
# [('bitcoin', 23), ('drop', 21), ('price', 18), ('go', 18), ('00', 15), ('just', 13), ('think', 12)]
# ------------1024
# [('buy', 16), ('year', 12), ('bitcoin', 9), ('price', 8), ('just', 8), ('like', 7), ('go', 6)]
# ------------1025
# [('finex', 19), ('bitcoin', 9), ('fuck', 6), ('delay', 6), ('process', 6), ('arb', 5), ('withdraw', 5)]
# ------------1026
# [('ppc', 11), ('bitcoin', 6), ('short', 5), ('nubit', 5), ('go', 5), ('mine', 4), ('hedg', 4)]
# ------------1027
# [('buy', 3), ('mistak', 3), ('i3', 2), ('kym', 2), ('cdn', 2), ('photo', 2), ('imag', 2)]
# ------------1028
# [('price', 24), ('sell', 14), ('good', 12), ('bitcoin', 12), ('halv', 12), ('hold', 11), ('short', 10)]
# ------------1029
# [('sleep', 11), ('bitcoin', 10), ('price', 8), ('watch', 6), ('can', 6), ('check', 6), ('don', 6)]
# ------------1030
# [('bitcoin', 28), ('price', 23), ('hold', 18), ('buy', 15), ('happi', 12), ('like', 9), ('peopl', 9)]
# ------------1031
# [('bitcoin', 9), ('peopl', 7), ('realli', 4), ('news', 3), ('articl', 3), ('mani', 3), ('don', 3)]
# ------------1032
# [('bitcoin', 6), ('sell', 5), ('buy', 5), ('just', 5), ('50', 4), ('big', 3), ('back', 3)]
# ------------1033
# [('bitcoin', 234), ('term', 200), ('long', 190), ('hold', 139), ('invest', 95), ('peopl', 91), ('can', 87)]
# ------------1034
# [('bitcoin', 44), ('year', 42), ('happen', 31), ('reach', 30), ('think', 30), ('possibl', 29), ('price', 28)]
# ------------1035
# [('bitcoin', 42), ('price', 41), ('think', 16), ('care', 15), ('now', 15), ('just', 15), ('still', 12)]
# ------------1036
# [('gox', 12), ('sell', 9), ('order', 9), ('buy', 8), ('use', 7), ('trade', 6), ('interfac', 6)]
# ------------1037
# [('bitcoin', 3), ('right', 3), ('just', 2), ('wallet', 2), ('fun', 2), ('put', 2), ('now', 2)]
# ------------1038
# [('bank', 3), ('receiv', 2), ('letter', 2), ('state', 2), ('time', 2), ('can', 2), ('invest', 2)]
# ------------1039
# [('bitcoin', 33), ('just', 16), ('go', 15), ('can', 10), ('like', 10), ('time', 9), ('freak', 9)]
# ------------1040
# [('bitcoin', 12), ('can', 4), ('hour', 4), ('price', 4), ('open', 4), ('turnov', 4), ('share', 4)]
# ------------1041
# [('000', 2), ('number', 2), ('account', 2), ('download', 2), ('just', 1), ('miner', 1), ('economist', 1)]
# ------------1042
# [('price', 37), ('bitcoin', 36), ('peopl', 18), ('sell', 15), ('now', 15), ('month', 12), ('can', 12)]
# ------------1043
# [('bitcoin', 221), ('price', 96), ('valu', 54), ('go', 42), ('peopl', 41), ('currenc', 40), ('get', 39)]
# ------------1044
# [('bitcoin', 7), ('show', 5), ('today', 4), ('talk', 3), ('he', 2), ('financi', 2), ('segment', 2)]
# ------------1045
# [('bitcoin', 3), ('money', 3), ('price', 2), ('last', 2), ('15', 2), ('stabl', 2), ('week', 2)]
# ------------1046
# [('bitcoin', 8), ('updat', 5), ('like', 4), ('peopl', 4), ('googl', 4), ('know', 3), ('lag', 3)]
# ------------1047
# [('bitcoin', 16), ('price', 8), ('e', 8), ('exchang', 7), ('now', 7), ('arbitrag', 7), ('like', 7)]
# ------------1048
# [('1', 4), ('bitcoin', 2), ('gm', 2), ('gold', 2), ('7', 2), ('23', 2), ('now', 1)]
# ------------1049
# [('don', 2), ('buy', 2), ('let', 1), ('us', 1), ('know', 1), ('crash', 1), ('thank', 1)]
# ------------1050
# [('bitcoin', 9), ('just', 5), ('gox', 4), ('come', 4), ('buy', 4), ('ll', 4), ('50', 3)]
# ------------1051
# [('think', 4), ('tea', 3), ('correct', 3), ('don', 2), ('see', 2), ('second', 2), ('upward', 2)]
# ------------1052
# [('got', 3), ('coin', 3), ('use', 3), ('400', 2), ('500', 2), ('10k', 2), ('virtex', 2)]
# ------------1053
# [('year', 23), ('bitcoin', 23), ('price', 22), ('think', 16), ('see', 14), ('100k', 10), ('time', 10)]
# ------------1054
# [('bitcoin', 10), ('peopl', 5), ('dump', 4), ('panic', 4), ('go', 4), ('buy', 4), ('time', 4)]
# ------------1055
# [('bitcoin', 19), ('trade', 12), ('sell', 9), ('buy', 8), ('market', 7), ('good', 7), ('news', 6)]
# ------------1056
# [('use', 5), ('trade', 4), ('withdrawl', 3), ('fee', 3), ('vircurex', 2), ('fund', 2), ('fiat', 2)]
# ------------1057
# [('bitcoin', 21), ('gox', 15), ('like', 14), ('get', 12), ('now', 12), ('bitcoinbuild', 9), ('0', 9)]
# ------------1058
# [('lawski', 3), ('reddit', 3), ('benjamin', 2), ('speaker', 2), ('find', 2), ('play', 2), ('post', 2)]
# ------------1059
# [('price', 36), ('sell', 20), ('bitcoin', 18), ('coin', 17), ('buy', 17), ('bot', 17), ('see', 16)]
# ------------1060
# [('0', 10), ('chart', 4), ('1', 4), ('2011', 4), ('06', 4), ('buy', 3), ('share', 3)]
# ------------1061
# [('bitcoin', 46), ('price', 20), ('think', 18), ('can', 15), ('go', 14), ('time', 12), ('year', 12)]
# ------------1062
# [('bitcoin', 10), ('make', 7), ('event', 6), ('apocalyps', 6), ('just', 5), ('magnet', 5), ('thing', 5)]
# ------------1063
# [('price', 15), ('bitcoin', 13), ('exchang', 11), ('happen', 10), ('news', 10), ('hack', 10), ('can', 7)]
# ------------1064
# [('privaci', 18), ('appl', 10), ('use', 8), ('right', 7), ('can', 7), ('end', 7), ('phone', 6)]
# ------------1065
# [('miss', 7), ('around', 6), ('quarter', 5), ('expect', 5), ('still', 5), ('go', 5), ('appl', 4)]
# ------------1066
# [('appl', 23), ('job', 14), ('pay', 13), ('bitcoin', 9), ('even', 9), ('steve', 9), ('applepay', 8)]
# ------------1067
# [('appl', 28), ('bitcoin', 22), ('app', 14), ('can', 14), ('allow', 11), ('wallet', 7), ('android', 7)]
# ------------1068
# [('bitcoin', 15), ('appl', 9), ('use', 5), ('accept', 5), ('can', 4), ('think', 4), ('go', 4)]
# ------------1069
# [('bitcoin', 23), ('appl', 9), ('money', 7), ('paid', 5), ('like', 5), ('invest', 4), ('get', 4)]
# ------------1070
# [('1000', 8), ('bitcoin', 8), ('closer', 8), ('3', 8), ('100', 7), ('digit', 6), ('365', 6)]
# ------------1071
# [('200', 5), ('1', 3), ('2', 3), ('level', 2), ('one', 2), ('etc', 2), ('price', 2)]
# ------------1072
# [('hold', 3), ('profit', 3), ('now', 2), ('dont', 1), ('anyth', 1), ('almost', 1), ('peak', 1)]
# ------------1073
# [('bitstamp', 5), ('app', 4), ('use', 3), ('trade', 3), ('mobil', 2), ('phone', 2), ('tabtrad', 2)]
# ------------1074
# [('record', 3), ('april', 3), ('11', 3), ('time', 3), ('bitcoin', 3), ('666', 3), ('purpos', 2)]
# ------------1075
# [('bitcoin', 3), ('p', 2), ('today', 1), ('class', 1), ('stuff', 1), ('went', 1), ('250', 1)]
# ------------1076
# [('crash', 7), ('price', 6), ('flash', 5), ('peopl', 5), ('sell', 5), ('bubbl', 5), ('thing', 5)]
# ------------1077
# [('ddo', 14), ('can', 8), ('attack', 6), ('just', 5), ('bitcoinchart', 4), ('websit', 4), ('site', 4)]
# ------------1078
# [('tonycolebi', 4), ('share', 2), ('2013', 2), ('04', 2), ('12_bitcoin_growth', 2), ('bitcoin', 2), ('can', 1)]
# ------------1079
# [('bitcoin', 16), ('bank', 16), ('buy', 14), ('exchang', 14), ('account', 13), ('price', 9), ('sell', 8)]
# ------------1080
# [('http', 7), ('vote', 7), ('surveymonkey', 5), ('bitcoin', 5), ('price', 5), ('survey', 4), ('result', 4)]
# ------------1081
# [('18th', 4), ('peopl', 3), ('worri', 3), ('bitcoin', 3), ('ye', 2), ('day', 2), ('read', 1)]
# ------------1082
# [('bitcoin', 20), ('use', 9), ('peopl', 9), ('money', 8), ('mean', 6), ('buy', 6), ('advantag', 6)]
# ------------1083
# [('bitcoin', 16), ('think', 8), ('go', 7), ('buy', 6), ('4', 6), ('20', 6), ('effect', 6)]
# ------------1084
# [('imag', 2), ('bayimg', 2), ('fbc4178ed36dbaee87cee432a6cbd1e597a07975', 2), ('tire', 2), ('answer', 2), ('best', 1), ('guess', 1)]
# ------------1085
# [('trend', 4), ('imgur', 4), ('still', 3), ('rise', 3), ('upward', 3), ('googl', 2), ('last', 2)]
# ------------1086
# [('articl', 5), ('window', 5), ('xp', 5), ('april', 4), ('8', 4), ('atm', 4), ('machin', 4)]
# ------------1087
# [('april', 3), ('fool', 3), ('cute', 2), ('calendar', 2), ('imag', 2), ('en', 2), ('teaser', 2)]
# ------------1088
# [('youtub', 2), ('watch', 2), ('v', 2), ('1ytceuuw2_a', 2), ('sure', 1), ('hope', 1), ('caus', 1)]
# ------------1089
# [('know', 4), ('say', 3), ('bitcoin', 2), ('fool', 2), ('time', 2), ('3', 2), ('5', 2)]
# ------------1090
# [('arbitrag', 3), ('peopl', 3), ('account', 3), ('run', 2), ('price', 2), ('chines', 2), ('cni', 2)]
# ------------1091
# [('bitstamp', 14), ('gox', 13), ('price', 13), ('indic', 6), ('spread', 6), ('get', 5), ('potenti', 5)]
# ------------1092
# [('websit', 6), ('bitcoin', 4), ('arbitrag', 2), ('chart', 2), ('yellow', 2), ('rememb', 2), ('find', 2)]
# ------------1093
# [('bitcoin', 19), ('gox', 15), ('arbitrag', 13), ('exchang', 11), ('market', 10), ('can', 10), ('usd', 9)]
# ------------1094
# [('bitcoin', 13), ('make', 4), ('ebay', 4), ('item', 4), ('good', 3), ('use', 3), ('chargeback', 3)]
# ------------1095
# [('bitcoin', 33), ('alt', 21), ('coin', 14), ('price', 12), ('can', 12), ('altcoin', 10), ('market', 9)]
# ------------1096
# [('counterfeit', 2), ('china', 2), ('bitcoin', 2), ('walnut', 1), ('sold', 1), ('still', 1), ('imposs', 1)]
# ------------1097
# [('gox', 8), ('bitcoin', 3), ('move', 3), ('day', 2), ('announc', 2), ('exchang', 2), ('interest', 2)]
# ------------1098
# [('imageshack', 14), ('us', 14), ('photo', 4), ('imag', 4), ('moonan', 3), ('cycl', 3), ('deadmoonv', 3)]
# ------------1099

# %% [markdown]
# # LDA

# %%
import gensim

# %%
import datetime

# %%
from gensim import corpora, models

a = datetime.datetime.now()

dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

b = datetime.datetime.now()
c = b - a

# %%
print(c)
# Out:
# 0:00:19.580105

# %%
a = datetime.datetime.now()
damodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=30, id2word = dictionary, passes=20)
b = datetime.datetime.now()
c = b - a

# %%
print( c)
# Out:
# 0:05:19.709480

# %%
from sklearn.externals import joblib
joblib.dump(damodel, 'LDA_model.pkl')
# Out:
# ['LDA_model.pkl']

# %%
damodel = joblib.load('LDA_model.pkl')

# %%
["m", "import",  "import", "http", "li", "b", "style" , "font", "span","hr", "d" , "jpg", "png" ]
# Out:
# ['m',
#  'import',
#  'import',
#  'http',
#  'li',
#  'b',
#  'style',
#  'font',
#  'span',
#  'hr',
#  'd',
#  'jpg',
#  'png']

# %%
for i in damodel.print_topics(num_topics=50, num_words=50):
    print(i)
    print('-----------------')
# Out:
# -----------------
# (28, '0.028*"analysi" + 0.016*"english" + 0.016*"index" + 0.015*"bit" + 0.014*"bitcoin" + 0.014*"php" + 0.013*"sky" + 0.010*"trend" + 0.008*"currenc" + 0.008*"democurr" + 0.007*"coin" + 0.007*"can" + 0.007*"today" + 0.006*"time" + 0.006*"ifc" + 0.005*"china" + 0.005*"00" + 0.005*"good" + 0.005*"market" + 0.005*"peopl" + 0.005*"author" + 0.004*"maker" + 0.004*"chines" + 0.003*"much" + 0.003*"just" + 0.003*"0" + 0.003*"money" + 0.003*"find" + 0.003*"bad" + 0.003*"price" + 0.003*"think" + 0.003*"poster" + 0.003*"may" + 0.003*"surveymonkey" + 0.003*"world" + 0.003*"guy" + 0.003*"beij" + 0.003*"litecoin" + 0.003*"democurrencytoday" + 0.003*"16" + 0.003*"altcoin" + 0.003*"februari" + 0.002*"buy" + 0.002*"use" + 0.002*"like" + 0.002*"thank" + 0.002*"9" + 0.002*"rise" + 0.002*"democrat" + 0.002*"gmt"')
# -----------------
# (29, '0.023*"bitcoin" + 0.014*"price" + 0.012*"buy" + 0.010*"just" + 0.009*"go" + 0.008*"like" + 0.008*"now" + 0.008*"time" + 0.007*"market" + 0.007*"sell" + 0.007*"peopl" + 0.007*"get" + 0.007*"can" + 0.007*"coin" + 0.006*"think" + 0.005*"back" + 0.005*"good" + 0.005*"see" + 0.005*"one" + 0.005*"make" + 0.005*"day" + 0.005*"don" + 0.004*"know" + 0.004*"look" + 0.004*"money" + 0.004*"trade" + 0.004*"still" + 0.004*"much" + 0.004*"exchang" + 0.004*"drop" + 0.003*"right" + 0.003*"even" + 0.003*"way" + 0.003*"say" + 0.003*"want" + 0.003*"take" + 0.003*"happen" + 0.003*"long" + 0.003*"1" + 0.003*"realli" + 0.003*"2" + 0.003*"thing" + 0.003*"gox" + 0.003*"crash" + 0.003*"re" + 0.003*"well" + 0.003*"come" + 0.003*"week" + 0.003*"order" + 0.003*"100"')
# -----------------

# %%
from itertools import chain
# Assigns the topics to the documents in corpus
lda_corpus = damodel[corpus]

# Find the threshold, let's set the threshold to be 1/#clusters,
# To prove that the threshold is sane, we average the sum of all probabilities:
scores = list(chain(*[[score for topic_id,score in topic] for topic in [doc for doc in lda_corpus]]))
threshold = sum(scores)/len(scores)
print (threshold)
print()

cluster1 = [j for i,j in zip(lda_corpus,texts) if i[0][1] > threshold]
# cluster2 = [j for i,j in zip(lda_corpus,texts) if i[1][1] > threshold]
# cluster3 = [j for i,j in zip(lda_corpus,texts) if i[2][1] > threshold]
# cluster4 = [j for i,j in zip(lda_corpus,texts) if i[3][1] > threshold]
# cluster5 = [j for i,j in zip(lda_corpus,texts) if i[4][1] > threshold]

print (cluster1)
# print( cluster2)
# print( cluster3)
# print( cluster4)
# print( cluster5)
# Out:
# 0.2743334400563918
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
# (28, '0.028*"analysi" + 0.016*"english" + 0.016*"index" + 0.015*"bit" + 0.014*"bitcoin" + 0.014*"php" + 0.013*"sky" + 0.010*"trend" + 0.008*"currenc" + 0.008*"democurr" + 0.007*"coin" + 0.007*"can" + 0.007*"today" + 0.006*"time" + 0.006*"ifc"')

# %%
damodel.get_document_topics(corpus[1])
# Out:
# [(19, 0.9940147)]

# %% [markdown]
# -----------------

# %%
list_message[0]
# Out:
# 'Even before I saw how much impact the upcoming fork was having I predicted 6-7K easily by end of year.&nbsp; Much more news about BTC and a lot more adoption.      Now with Fork getting closer everyone is dumping alt coins to buy BTC and get the "free"&nbsp; BTG coins.&nbsp; Has created a selling of alt coin and buying frenzy of BTC.               I dumped a decent amount into alt coins in the last week as they had dropped 25-60% in about 7 days across the board.&nbsp; Sure makes for a great buying opportunity of alt coins.&nbsp;      You get alts for cheaper and added value of your BTC to buy them with.&nbsp;           BTC is up $1470 since last week&nbsp; :o&nbsp; &nbsp;Smashed through 5K barrier like it didn\'t exist. I dont see 6K being a barrier either with this kind of frenzy. 7K is likely and I wouldn\'t be surprised at all to see it touch 8K. There is BTC Gold in them thar hills........&nbsp; &nbsp;;D                    &nbsp; 1470 in 1 week is huge, massive.     Next step is 7000.'

# %%
texts = []
for msg in range(len(list_message)):
    # Convert the document into lowercase
    raw = list_message[msg].lower()
    # Tokenize the document: tokens
    tokens = tokenizer.tokenize(raw)
    
    stopped_tokens = [i for i in tokens if not i in en_stop]
    stopped_tokens = [i for i in stopped_tokens if not i in remove_words]
    stemmed_tokens = [p_stemmer.stem(i) for i in stopped_tokens]
    texts.append(stemmed_tokens)

# %%
# Import Dictionary
from gensim.corpora.dictionary import Dictionary

# Create a Dictionary from the articles: dictionary
dictionary = Dictionary(articles)

# Select the id for "computer": computer_id
computer_id = dictionary.token2id.get("computer")

# Use computer_id with the dictionary to print the word
print(dictionary.get(computer_id))

# Create a MmCorpus: corpus
corpus = [dictionary.doc2bow(article) for article in articles]

# Print the first 10 word ids with their frequency counts from the fifth document
print(corpus[4][:10])
corpus[0]

# %%
# Save the fifth document: doc
doc = corpus[4]

# Sort the doc for frequency: bow_doc
bow_doc = sorted(doc, key=lambda w: w[1], reverse=True)

# Print the top 5 words of the document alongside the count
for word_id, word_count in bow_doc[:5]:
    print(dictionary.get(word_id), word_count)
    
# Create the defaultdict: total_word_count
total_word_count = defaultdict(int)
for word_id, word_count in itertools.chain.from_iterable(corpus):
    total_word_count[word_id] += word_count

# Create a sorted list from the defaultdict: sorted_word_count 
sorted_word_count = sorted(total_word_count.items(), key=lambda w: w[1], reverse=True) 

# Print the top 5 words across all documents alongside the count
for word_id, word_count in sorted_word_count[:5]:
    print(dictionary.get(word_id), word_count)

# %%
wnl = WordNetLemmatizer()

# %%
print (wnl.lemmatize('go', 'n'))
# Out:
# go

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
 
ps = PorterStemmer()
 
sentence = "gaming, the gamers play games better slower"
words = word_tokenize(sentence)
 
for word in words:
    print(word + ":" + ps.stem(word))
# Out:
# gaming:game
# ,:,
# the:the
# gamers:gamer
# play:play
# games:game
# better:better
# slower:slower

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")
print(stemmer.stem("slower"))
# Out:
# slower
