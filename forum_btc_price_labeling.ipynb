# %%
import pandas as pd
import numpy as np
import datetime

# %%
df = pd.read_csv('all_data_cleaned_new.csv')

# %%
len(df)
# Out:
# 1046382

# %%
df_price = pd.read_csv('bitcoin_data_one_minute_2017_2018.csv')

# %%
df_new = pd.DataFrame(columns=df.columns)

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 8 columns):
# timestamp         0 non-null object
# category_id       0 non-null object
# topic_id          0 non-null object
# topic_title       0 non-null object
# message_number    0 non-null object
# message_author    0 non-null object
# message_text      0 non-null object
# quoteheader       0 non-null object
# dtypes: object(8)
# memory usage: 0.0+ bytes

# %%
df_new = df[df['timestamp']>= 1451606400]

# %%
len(df_new)
# Out:
# 503816

# %%
df[1483228800<='timestamp' ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-01de3a71117d> in <module>()
# ----> 1 df[1483228800<='timestamp' ]
#
# TypeError: '<=' not supported between instances of 'int' and 'str'

# %%
df_new
# Out:
#        timestamp category_id topic_id  \
# 2042  1505046436           7  2165658
# 2043  1505048987           7  2165658
# 2044  1505049051           7  2165658
# 2045  1505049076           7  2165658
# 2046  1505049635           7  2165658
# 2047  1505049873           7  2165658
# 2048  1505050474           7  2165658
# 2049  1505050834           7  2165658
# 2050  1505051103           7  2165658
# 2051  1505051854           7  2165658
# 2052  1505051980           7  2165658
# 2053  1505052696           7  2165658
# 2054  1505053149           7  2165658
# 2055  1505053393           7  2165658
# 2056  1505054375           7  2165658
# 2057  1505054516           7  2165658
# 2058  1505054981           7  2165658
# 2059  1505055272           7  2165658
# 2060  1505055914           7  2165658
# 2061  1505057544           7  2165658
# 2062  1505057719           7  2165658
# 2063  1505059618           7  2165658
# 2064  1505059863           7  2165658
# ...

# %%
df_price.head(20)

# %%
for i in range(df_price.size - 1):
    print(df_price.iloc[i])
