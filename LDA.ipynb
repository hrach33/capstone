# %% [markdown]
# # Setup

# %%
from tqdm import tqdm
import pandas as pd
import numpy as np
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
import glob
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# /Users/hrachkhachatryan/anaconda3/lib/python3.6/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %% [markdown]
# # Data

# %%
path =r'./cleaned_data/' # use your path
allFiles = glob.glob(path + "/*.csv")
df = pd.DataFrame()

list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None)
    list_.append(df)

df = pd.concat(list_)
df.reset_index(inplace=True, drop=True)

# %%
sid = SentimentIntensityAnalyzer()

# %%
sid.polarity_scores("awsaome football game")
# Out:
# {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0}

# %%
df.head()
# Out:
#     timestamp  category_id  topic_id  \
# 0  1514379921           57   2653937
# 1  1514380918           57   2653937
# 2  1514381025           57   2653937
# 3  1514382464           57   2653937
# 4  1514384271           57   2653937
#
#                                     topic_title  message_number  \
# 0  16.5K will be the major resistance for BTC ?               1
# 1  16.5K will be the major resistance for BTC ?               2
# 2  16.5K will be the major resistance for BTC ?               3
# 3  16.5K will be the major resistance for BTC ?               4
# 4  16.5K will be the major resistance for BTC ?               5
#
#     message_author                                       message_text  \
# 0  AICoin_Official  As you can see, price started a correction imm...
# 1           nokati  And&nbsp; who is this Kuang Ren with such a wi...
# 2         fabiorem  Yes, theres a lot of resistance at this level,...
# 3       heringasem  With the current price fluctuations the price ...
# 4        CuDoCuDau                             You should buy bitcoin
#
#                                          quoteheader
# 0                                                NaN
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  ['<div class="quoteheader"><a href="https://bi...

# %%
df['pos'] = 0.
df['neg'] = 0.
df['neu'] = 0.
df['compound'] = 0.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41328 entries, 0 to 41327
# Data columns (total 12 columns):
# timestamp         41328 non-null int64
# category_id       41328 non-null int64
# topic_id          41328 non-null int64
# topic_title       41328 non-null object
# message_number    41328 non-null int64
# message_author    41327 non-null object
# message_text      41111 non-null object
# quoteheader       41324 non-null object
# pos               41328 non-null float64
# neg               41328 non-null float64
# neu               41328 non-null float64
# compound          41328 non-null float64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 3.8+ MB

# %%
## LABELING POSTS AS NEGATIVE, POSITIVE OR NEUTRAL

for i, row in df.iterrows():
    pol_scores = sid.polarity_scores(str(row.message_text))
    df.set_value(i,'pos', float(pol_scores['pos']))
    df.set_value(i,'neg', float(pol_scores['neg']))
    df.set_value(i,'neu', float(pol_scores['neu']))
    df.set_value(i,'compound', float(pol_scores['compound']))
# Out:
# /Users/hrachkhachatryan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """
# /Users/hrachkhachatryan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /Users/hrachkhachatryan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# /Users/hrachkhachatryan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
df.to_csv('pos_neg.csv')

# %%
df.tail()
# Out:
#         timestamp  category_id  topic_id topic_title  message_number  \
# 41323  1411050454           57    787222           .               2
# 41324  1411050918           57    787222           .               3
# 41325  1411051112           57    787222           .               4
# 41326  1411075852           57    787222           .               5
# 41327  1411075887           57    787222           .               6
#
#          message_author                                       message_text  \
# 41323           Hfertig       And back down to 8365 without a short squ...
# 41324              klee                    So what is their next move? Up?
# 41325           Hfertig       Difficult to say. Selling pressure is sti...
# 41326         molecular       doesn't the same go for the $20 millions ...
# 41327  grappa_barricata  If i may add something, a sizable part of the ...
#
#                                              quoteheader pos neg neu compound
# 41323  ['<div class="quoteheader"><a href="https://bi...
# 41324                                                 []
# 41325  ['<div class="quoteheader"><a href="https://bi...
# 41326  ['<div class="quoteheader"><a href="https://bi...
# 41327                                                 []

# %%
df.tail()
# Out:
#         timestamp  category_id  topic_id topic_title  message_number  \
# 41323  1411050454           57    787222           .               2
# 41324  1411050918           57    787222           .               3
# 41325  1411051112           57    787222           .               4
# 41326  1411075852           57    787222           .               5
# 41327  1411075887           57    787222           .               6
#
#          message_author                                       message_text  \
# 41323           Hfertig       And back down to 8365 without a short squ...
# 41324              klee                    So what is their next move? Up?
# 41325           Hfertig       Difficult to say. Selling pressure is sti...
# 41326         molecular       doesn't the same go for the $20 millions ...
# 41327  grappa_barricata  If i may add something, a sizable part of the ...
#
#                                              quoteheader
# 41323  ['<div class="quoteheader"><a href="https://bi...
# 41324                                                 []
# 41325  ['<div class="quoteheader"><a href="https://bi...
# 41326  ['<div class="quoteheader"><a href="https://bi...
# 41327                                                 []

# %% [markdown]
# ---

# %% [markdown]
# # Message Concatenating:

# %%
grouped_topics = df.groupby(df.topic_title).groups

# %%
dict_topic = {}
for tit in tqdm(grouped_topics.keys()):
    sentence = (df.message_text[grouped_topics[tit]].values)
    dict_topic.update({tit: ''.join(str(v) for v in sentence) })
# Out:
# 100%|██████████| 1100/1100 [00:00<00:00, 1827.90it/s]

# %%
list_message = []
for i in dict_topic.keys():
    list_message.append(dict_topic[i])

# %% [markdown]
# -------------

# %% [markdown]
# # LDA

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')  #match any word characters until it reaches a non-word character, like a space.

# %%
raw = list_message[0].lower()
tokens = tokenizer.tokenize(raw)

# %% [markdown]
# # Stop words

# %%
from stop_words import get_stop_words

# create English stop words list
en_stop = get_stop_words('en')

# %%
# remove stop words from tokens
stopped_tokens = [i for i in tokens if not i in en_stop]
print(stopped_tokens)
# Out:
# ['even', 'saw', 'much', 'impact', 'upcoming', 'fork', 'predicted', '6', '7k', 'easily', 'end', 'year', 'nbsp', 'much', 'news', 'btc', 'lot', 'adoption', 'now', 'fork', 'getting', 'closer', 'everyone', 'dumping', 'alt', 'coins', 'buy', 'btc', 'get', 'free', 'nbsp', 'btg', 'coins', 'nbsp', 'created', 'selling', 'alt', 'coin', 'buying', 'frenzy', 'btc', 'dumped', 'decent', 'amount', 'alt', 'coins', 'last', 'week', 'dropped', '25', '60', '7', 'days', 'across', 'board', 'nbsp', 'sure', 'makes', 'great', 'buying', 'opportunity', 'alt', 'coins', 'nbsp', 'get', 'alts', 'cheaper', 'added', 'value', 'btc', 'buy', 'nbsp', 'btc', '1470', 'since', 'last', 'week', 'nbsp', 'o', 'nbsp', 'nbsp', 'smashed', '5k', 'barrier', 'like', 'didn', 't', 'exist', 'dont', 'see', '6k', 'barrier', 'either', 'kind', 'frenzy', '7k', 'likely', 'wouldn', 't', 'surprised', 'see', 'touch', '8k', 'btc', 'gold', 'thar', 'hills', 'nbsp', 'nbsp', 'd', 'nbsp', '1470', '1', 'week', 'huge', 'massive', 'next', 'step', '7000']

# %% [markdown]
# # Our words

# %%
remove_words = ['will','s' , 'nbsp', 't', 'com', 'http', 'amp', '1xnk8bc', 'href', 'oto', 'www' ]
stopped_tokens = [i for i in stopped_tokens if not i in remove_words]
print(stopped_tokens)
# Out:
# ['even', 'saw', 'much', 'impact', 'upcoming', 'fork', 'predicted', '6', '7k', 'easily', 'end', 'year', 'much', 'news', 'btc', 'lot', 'adoption', 'now', 'fork', 'getting', 'closer', 'everyone', 'dumping', 'alt', 'coins', 'buy', 'btc', 'get', 'free', 'btg', 'coins', 'created', 'selling', 'alt', 'coin', 'buying', 'frenzy', 'btc', 'dumped', 'decent', 'amount', 'alt', 'coins', 'last', 'week', 'dropped', '25', '60', '7', 'days', 'across', 'board', 'sure', 'makes', 'great', 'buying', 'opportunity', 'alt', 'coins', 'get', 'alts', 'cheaper', 'added', 'value', 'btc', 'buy', 'btc', '1470', 'since', 'last', 'week', 'o', 'smashed', '5k', 'barrier', 'like', 'didn', 'exist', 'dont', 'see', '6k', 'barrier', 'either', 'kind', 'frenzy', '7k', 'likely', 'wouldn', 'surprised', 'see', 'touch', '8k', 'btc', 'gold', 'thar', 'hills', 'd', '1470', '1', 'week', 'huge', 'massive', 'next', 'step', '7000']

# %% [markdown]
# # Stemming

# %%
from nltk.stem.porter import PorterStemmer

# Create p_stemmer of class PorterStemmer
p_stemmer = PorterStemmer()

# Create lemmatizer
wnl = WordNetLemmatizer()

# %%
# stem token
stemmed_tokens = [p_stemmer.stem(i) for i in stopped_tokens]

print(stemmed_tokens)
# Out:
# ['even', 'saw', 'much', 'impact', 'upcom', 'fork', 'predict', '6', '7k', 'easili', 'end', 'year', 'much', 'news', 'btc', 'lot', 'adopt', 'now', 'fork', 'get', 'closer', 'everyon', 'dump', 'alt', 'coin', 'buy', 'btc', 'get', 'free', 'btg', 'coin', 'creat', 'sell', 'alt', 'coin', 'buy', 'frenzi', 'btc', 'dump', 'decent', 'amount', 'alt', 'coin', 'last', 'week', 'drop', '25', '60', '7', 'day', 'across', 'board', 'sure', 'make', 'great', 'buy', 'opportun', 'alt', 'coin', 'get', 'alt', 'cheaper', 'ad', 'valu', 'btc', 'buy', 'btc', '1470', 'sinc', 'last', 'week', 'o', 'smash', '5k', 'barrier', 'like', 'didn', 'exist', 'dont', 'see', '6k', 'barrier', 'either', 'kind', 'frenzi', '7k', 'like', 'wouldn', 'surpris', 'see', 'touch', '8k', 'btc', 'gold', 'thar', 'hill', 'd', '1470', '1', 'week', 'huge', 'massiv', 'next', 'step', '7000']

# %% [markdown]
# # tokenizing, removing stop words, stemmming

# %%
from collections import Counter

# %%
texts = []

remove_words = ['will','s' ,'bitcoin', 'just', 'get', 'use', 'now', 'solidx' 'people','bitfinex', 'think', 'maybe', 'imageshack', 'pt', 'em', 'img', 'nbsp', 't', 'com', 'http', 'amp', '1xnk8bc', 'href', 'oto', 'www', 'isn', 'etc', 'etf', 'tr', 'td', 'img', 'ath', 'xt', 'xp', 'php', 'img', 'gt', 'pboc', 'th', 'mtgox', 'cny', 'huobi',
 'm', 'import', 'st', 'lt', 'zhou' 'ok', 'color', 'can', "adam", "bitcoin", 'import', 'http', 'li', 'b', 'style' , 'font', 're', 'le', 'gif','span','hr', 'd' , 'jpg', 'png',  'am5om', 'fud', 'mt', 'th' 'hfebupaeo', 'ftdata', 'zbb', 'imgur', 'bite', 'uztgwi', 'podomatic']

map_words = {
    'btc': 'bitcoin',
    'bcc': 'bitcoin',
    'gbtc': 'bitcoin',
    'bitcoinca': 'bitcoin',
    'better': 'good',
    'increase': 'rise',
    'miner': 'mine',
    'winner': 'win'
}

for msg in tqdm(range(len(list_message))):
    raw = list_message[msg].lower()
    tokens = tokenizer.tokenize(raw)
    
    stopped_tokens = [i for i in tokens if not i in en_stop]
    stopped_tokens = [i for i in stopped_tokens if not i in remove_words]

    #   lemmatize tokents:  
    lemmatized_tokens = [wnl.lemmatize(i, 'a') for i in stopped_tokens]
    lemmatized_tokens = [wnl.lemmatize(i, 'n') for i in lemmatized_tokens]
    lemmatized_tokens = [wnl.lemmatize(i, 'v') for i in lemmatized_tokens]
    lemmatized_tokens = [wnl.lemmatize(i, 'r') for i in lemmatized_tokens]
    lemmatized_tokens = [wnl.lemmatize(i, 's') for i in lemmatized_tokens]
    
    #     stemmed_tokens = [p_stemmer.stem(i) for i in lemmatized_tokens]
    
    #   remove words:
    stemmed_tokens = [i for i in lemmatized_tokens if not i in remove_words]
    stemmed_tokens = [i for i in stemmed_tokens if not i in en_stop]
    d = pd.DataFrame({'z': stemmed_tokens})
    stemmed_tokens = d.replace(map_words)['z'].tolist()
    
    #   remove numeric values:
    alpha_only = [''.join(filter(str.isalpha, i))  for i in stemmed_tokens if len(''.join(filter(str.isalpha, i))) >1]
    texts.append(alpha_only)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-8b223860a30f> in <module>()
#      15 }
#      16
# ---> 17 for msg in tqdm(range(len(list_message))):
#      18     raw = list_message[msg].lower()
#      19     tokens = tokenizer.tokenize(raw)
#
# NameError: name 'list_message' is not defined

# %%
for i in (range(len(texts))):
    print(Counter(texts[i]).most_common(7))
    print('------------'+str(i))

# %%
flat_list = [item for sublist in texts for item in sublist]

# %%
len(flat_list)
# Out:
# 840580

# %%
Counter(flat_list).most_common()
# Out:
# [('price', 21745),
#  ('go', 11111),
#  ('see', 7671),
#  ('buy', 7577),
#  ('time', 7492),
#  ('bitcoin', 7461),
#  ('people', 7436),
#  ('year', 7133),
#  ('rise', 6339),
#  ('happen', 6132),
#  ('like', 5832),
#  ('sell', 5273),
#  ('good', 5221),
#  ('market', 5079),
#  ('make', 5003),
#  ('don', 4807),
#  ('even', 4660),
#  ('one', 4510),
#  ('coin', 4317),
#  ('high', 4311),
#  ('say', 4173),
#  ('know', 4056),
#  ('still', 3980),
#  ('day', 3953),
#  ('long', 3811),
#  ('reach', 3700),
#  ('much', 3678),
#  ('money', 3607),
#  ('value', 3381),
#  ('back', 3380),
#  ('right', 3314),
#  ('take', 3300),
#  ('come', 3230),
#  ('really', 3195),
#  ('hold', 3055),
#  ('month', 3005),
#  ('way', 2966),
#  ('also', 2965),
#  ('bitcoins', 2950),
#  ('look', 2926),
#  ('thing', 2905),
#  ('big', 2844),
#  ('next', 2822),
#  ('need', 2779),
#  ('new', 2718),
#  ('end', 2644),
#  ('low', 2619),
#  ('lot', 2584),
#  ('start', 2550),
#  ('want', 2547),
#  ('many', 2545),
#  ('well', 2503),
#  ('trade', 2496),
#  ('sure', 2467),
#  ('may', 2370),
#  ('around', 2368),
#  ('drop', 2294),
#  ('exchange', 2290),
#  ('mine', 2206),
#  ('dollar', 2138),
#  ('possible', 2102),
#  ('last', 2081),
#  ('expect', 2080),
#  ('mean', 2073),
#  ('wait', 2063),
#  ('already', 2047),
#  ('halve', 2038),
#  ('point', 2003),
#  ('keep', 1988),
#  ('profit', 1951),
#  ('week', 1949),
#  ('might', 1931),
#  ('seem', 1902),
#  ('usd', 1888),
#  ('future', 1846),
#  ('term', 1840),
#  ('never', 1801),
#  ('believe', 1768),
#  ('hope', 1768),
#  ('ll', 1767),
#  ('news', 1749),
#  ('currency', 1742),
#  ('since', 1719),
#  ('dump', 1678),
#  ('soon', 1658),
#  ('win', 1654),
#  ('something', 1630),
#  ('crash', 1627),
#  ('move', 1599),
#  ('another', 1599),
#  ('short', 1588),
#  ('level', 1586),
#  ('first', 1510),
#  ('probably', 1497),
#  ('give', 1485),
#  ('hit', 1482),
#  ('let', 1464),
#  ('bubble', 1417),
#  ('world', 1396),
#  ('today', 1394),
#  ('lose', 1391),
#  ('try', 1383),
#  ('every', 1379),
#  ('always', 1327),
#  ('bad', 1324),
#  ('yes', 1318),
#  ('actually', 1313),
#  ('hard', 1312),
#  ('current', 1307),
#  ('though', 1300),
#  ('fall', 1296),
#  ('reason', 1291),
#  ('amount', 1279),
#  ('enough', 1251),
#  ('ve', 1232),
#  ('nothing', 1229),
#  ('chart', 1228),
#  ('fiat', 1225),
#  ('post', 1224),
#  ('become', 1223),
#  ('pump', 1222),
#  ('doesn', 1218),
#  ('guess', 1204),
#  ('continue', 1196),
#  ('break', 1192),
#  ('prediction', 1191),
#  ('interest', 1183),
#  ('invest', 1182),
#  ('least', 1174),
#  ('far', 1174),
#  ('work', 1167),
#  ('order', 1163),
#  ('everyone', 1160),
#  ('real', 1159),
#  ('million', 1158),
#  ('change', 1140),
#  ('support', 1114),
#  ('volume', 1109),
#  ('number', 1070),
#  ('great', 1069),
#  ('little', 1068),
#  ('anything', 1054),
#  ('late', 1046),
#  ('yet', 1046),
#  ('small', 1041),
#  ('agree', 1039),
#  ('predict', 1029),
#  ('huge', 1027),
#  ('fast', 1025),
#  ('worth', 1023),
#  ('fork', 1020),
#  ('close', 1020),
#  ('likely', 1012),
#  ('pay', 1002),
#  ('stable', 994),
#  ('bank', 990),
#  ('two', 989),
#  ('gox', 988),
#  ('stop', 986),
#  ('run', 969),
#  ('pretty', 968),
#  ('gold', 965),
#  ('panic', 957),
#  ('per', 953),
#  ('investor', 951),
#  ('investment', 949),
#  ('ever', 949),
#  ('true', 947),
#  ('feel', 945),
#  ('guy', 942),
#  ('demand', 942),
#  ('china', 938),
#  ('fact', 935),
#  ('chance', 927),
#  ('problem', 924),
#  ('large', 921),
#  ('early', 918),
#  ('grow', 917),
#  ('cash', 914),
#  ('rate', 909),
#  ('correction', 907),
#  ('top', 895),
#  ('trend', 894),
#  ('thread', 890),
#  ('find', 888),
#  ('user', 888),
#  ('without', 886),
#  ('transaction', 878),
#  ('speculation', 878),
#  ('talk', 871),
#  ('put', 870),
#  ('stay', 869),
#  ('ago', 867),
#  ('quite', 866),
#  ('block', 866),
#  ('didn', 859),
#  ('tell', 854),
#  ('past', 853),
#  ('best', 851),
#  ('show', 840),
#  ('base', 826),
#  ('bear', 824),
#  ('dont', 817),
#  ('course', 816),
#  ('cause', 815),
#  ('someone', 803),
#  ('call', 803),
#  ('wrong', 801),
#  ('accept', 797),
#  ('yeah', 794),
#  ('understand', 790),
#  ('cheap', 775),
#  ('org', 774),
#  ('trader', 773),
#  ('wall', 771),
#  ('consider', 769),
#  ('adoption', 767),
#  ('range', 763),
#  ('hour', 761),
#  ('case', 759),
#  ('moment', 758),
#  ('watch', 753),
#  ('however', 751),
#  ('read', 744),
#  ('lol', 732),
#  ('place', 726),
#  ('nice', 726),
#  ('either', 724),
#  ('within', 724),
#  ('bull', 721),
#  ('ask', 718),
#  ('bottom', 716),
#  ('almost', 714),
#  ('growth', 713),
#  ('follow', 712),
#  ('strong', 711),
#  ('matter', 710),
#  ('risk', 709),
#  ('must', 708),
#  ('rally', 704),
#  ('anyone', 700),
#  ('everything', 695),
#  ('able', 695),
#  ('crypto', 691),
#  ('due', 684),
#  ('opinion', 682),
#  ('near', 681),
#  ('impossible', 669),
#  ('easy', 667),
#  ('supply', 661),
#  ('dip', 659),
#  ('gain', 658),
#  ('kind', 654),
#  ('leave', 651),
#  ('spend', 651),
#  ('doubt', 649),
#  ('forum', 646),
#  ('chinese', 641),
#  ('different', 639),
#  ('question', 637),
#  ('stock', 634),
#  ('part', 631),
#  ('create', 628),
#  ('double', 625),
#  ('system', 624),
#  ('wouldn', 620),
#  ('fee', 620),
#  ('whale', 612),
#  ('definitely', 599),
#  ('line', 595),
#  ('account', 588),
#  ('begin', 586),
#  ('bet', 586),
#  ('inherit', 584),
#  ('country', 578),
#  ('op', 577),
#  ('cost', 577),
#  ('away', 576),
#  ('august', 576),
#  ('government', 575),
#  ('exactly', 573),
#  ('idea', 572),
#  ('thank', 572),
#  ('business', 568),
#  ('position', 568),
#  ('fund', 566),
#  ('important', 566),
#  ('wallet', 562),
#  ('play', 560),
#  ('power', 547),
#  ('topic', 546),
#  ('average', 545),
#  ('bullish', 541),
#  ('hand', 539),
#  ('couple', 536),
#  ('company', 534),
#  ('surprise', 533),
#  ('happy', 533),
#  ('class', 531),
#  ('payment', 530),
#  ('mind', 528),
#  ('worry', 527),
#  ('issue', 525),
#  ('gonna', 524),
#  ('currently', 524),
#  ('network', 523),
#  ('period', 522),
#  ('limit', 520),
#  ('help', 520),
#  ('push', 519),
#  ('free', 517),
#  ('movement', 517),
#  ('january', 513),
#  ('analysis', 512),
#  ('medium', 509),
#  ('else', 509),
#  ('alt', 506),
#  ('major', 505),
#  ('unless', 502),
#  ('bring', 499),
#  ('bitstamp', 498),
#  ('instead', 498),
#  ('index', 495),
#  ('dream', 494),
#  ('turn', 493),
#  ('mark', 491),
#  ('loss', 490),
#  ('half', 488),
#  ('possibility', 488),
#  ('slow', 485),
#  ('cap', 483),
#  ('share', 483),
#  ('rich', 480),
#  ('fail', 478),
#  ('whole', 478),
#  ('compare', 475),
#  ('effect', 475),
#  ('positive', 475),
#  ('situation', 475),
#  ('hear', 473),
#  ('depend', 471),
#  ('potential', 470),
#  ('rather', 469),
#  ('touch', 468),
#  ('saw', 467),
#  ('normal', 466),
#  ('resistance', 463),
#  ('decrease', 462),
#  ('slowly', 461),
#  ('correct', 459),
#  ('especially', 459),
#  ('game', 457),
#  ('add', 456),
#  ('event', 454),
#  ('check', 454),
#  ('simply', 454),
#  ('remain', 453),
#  ('remember', 453),
#  ('set', 451),
#  ('th', 450),
#  ('december', 445),
#  ('open', 444),
#  ('size', 444),
#  ('asset', 442),
#  ('trust', 440),
#  ('miss', 439),
#  ('altcoins', 439),
#  ('others', 438),
#  ('peak', 437),
#  ('opportunity', 436),
#  ('target', 435),
#  ('old', 435),
#  ('jump', 435),
#  ('volatility', 432),
#  ('blockchain', 429),
#  ('im', 429),
#  ('sense', 425),
#  ('earn', 425),
#  ('life', 422),
#  ('result', 421),
#  ('wave', 420),
#  ('save', 420),
#  ('bitcointalk', 419),
#  ('holder', 417),
#  ('easily', 414),
#  ('assume', 413),
#  ('whatever', 410),
#  ('decide', 409),
#  ('achieve', 409),
#  ('plan', 407),
#  ('certain', 405),
#  ('recover', 404),
#  ('surely', 401),
#  ('whether', 401),
#  ('forget', 399),
#  ('person', 399),
#  ('care', 397),
#  ('side', 396),
#  ('economy', 395),
#  ('eventually', 394),
#  ('crazy', 394),
#  ('massive', 393),
#  ('history', 393),
#  ('example', 391),
#  ('please', 390),
#  ('drive', 390),
#  ('thousand', 390),
#  ('purchase', 386),
#  ('although', 386),
#  ('hop', 383),
#  ('service', 383),
#  ('bid', 382),
#  ('second', 378),
#  ('perhaps', 376),
#  ('financial', 374),
#  ('affect', 374),
#  ('completely', 372),
#  ('experience', 372),
#  ('control', 371),
#  ('lead', 370),
#  ('oh', 369),
#  ('moon', 369),
#  ('thats', 368),
#  ('community', 368),
#  ('till', 368),
#  ('factor', 366),
#  ('spread', 365),
#  ('cross', 364),
#  ('billion', 364),
#  ('word', 363),
#  ('shit', 362),
#  ('figure', 362),
#  ('anyway', 361),
#  ('wonder', 360),
#  ('safe', 359),
#  ('indeed', 359),
#  ('amazon', 359),
#  ('spike', 357),
#  ('store', 357),
#  ('realize', 354),
#  ('several', 353),
#  ('recent', 352),
#  ('single', 351),
#  ('sign', 350),
#  ('previous', 350),
#  ('technology', 350),
#  ('speculate', 349),
#  ('head', 349),
#  ('daily', 349),
#  ('inflation', 348),
#  ('imagine', 347),
#  ('love', 347),
#  ('state', 346),
#  ('tomorrow', 346),
#  ('fuck', 346),
#  ('nobody', 345),
#  ('scenario', 343),
#  ('scale', 343),
#  ('learn', 343),
#  ('live', 341),
#  ('quick', 338),
#  ('send', 336),
#  ('full', 336),
#  ('ban', 335),
#  ('haven', 334),
#  ('data', 333),
#  ('buyer', 333),
#  ('article', 332),
#  ('man', 331),
#  ('image', 331),
#  ('realistic', 330),
#  ('difficulty', 330),
#  ('exist', 329),
#  ('option', 328),
#  ('view', 327),
#  ('clear', 326),
#  ('november', 326),
#  ('allow', 325),
#  ('sit', 323),
#  ('fear', 323),
#  ('bitcoinica', 323),
#  ('negative', 322),
#  ('bounce', 321),
#  ('minute', 320),
#  ('occur', 319),
#  ('deal', 318),
#  ('anymore', 316),
#  ('action', 315),
#  ('quickly', 315),
#  ('difficult', 315),
#  ('wish', 315),
#  ('reward', 313),
#  ('yesterday', 312),
#  ('site', 311),
#  ('similar', 311),
#  ('ready', 310),
#  ('test', 310),
#  ('behind', 310),
#  ('aren', 309),
#  ('total', 309),
#  ('raise', 309),
#  ('return', 308),
#  ('sound', 308),
#  ('capital', 307),
#  ('certainly', 307),
#  ('fundamental', 307),
#  ('imo', 306),
#  ('write', 305),
#  ('build', 305),
#  ('wealth', 303),
#  ('significant', 302),
#  ('answer', 302),
#  ('merchant', 302),
#  ('obviously', 302),
#  ('reality', 301),
#  ('die', 300),
#  ('tax', 300),
#  ('difference', 299),
#  ('force', 297),
#  ('internet', 296),
#  ('ok', 295),
#  ('chain', 295),
#  ('prove', 295),
#  ('stupid', 294),
#  ('hype', 294),
#  ('mention', 293),
#  ('finally', 293),
#  ('sub', 290),
#  ('form', 289),
#  ('margin', 289),
#  ('troll', 288),
#  ('segwit', 288),
#  ('altcoin', 288),
#  ('strategy', 285),
#  ('rest', 284),
#  ('btc', 283),
#  ('march', 282),
#  ('satoshi', 282),
#  ('valign', 282),
#  ('notice', 281),
#  ('friend', 280),
#  ('weekend', 280),
#  ('serious', 279),
#  ('cryptocurrency', 279),
#  ('manipulate', 279),
#  ('mass', 279),
#  ('stuff', 278),
#  ('smart', 278),
#  ('wont', 278),
#  ('towards', 275),
#  ('hopefully', 275),
#  ('decline', 274),
#  ('suggest', 274),
#  ('claim', 271),
#  ('net', 270),
#  ('april', 265),
#  ('digit', 265),
#  ('date', 264),
#  ('sorry', 264),
#  ('dead', 263),
#  ('july', 263),
#  ('include', 262),
#  ('indicator', 262),
#  ('seller', 260),
#  ('enjoy', 260),
#  ('st', 259),
#  ('split', 259),
#  ('hack', 259),
#  ('decision', 259),
#  ('possibly', 258),
#  ('pressure', 257),
#  ('enter', 257),
#  ('step', 256),
#  ('comment', 256),
#  ('pull', 256),
#  ('simple', 256),
#  ('impact', 255),
#  ('collapse', 254),
#  ('stick', 254),
#  ('unlikely', 254),
#  ('otherwise', 253),
#  ('bearish', 252),
#  ('personally', 252),
#  ('type', 251),
#  ('transfer', 251),
#  ('online', 251),
#  ('book', 251),
#  ('actual', 250),
#  ('steady', 250),
#  ('volatile', 250),
#  ('edit', 249),
#  ('direction', 249),
#  ('usually', 248),
#  ('speculator', 247),
#  ('explain', 247),
#  ('optimistic', 247),
#  ('mid', 247),
#  ('thus', 246),
#  ('sort', 245),
#  ('majority', 245),
#  ('msg', 245),
#  ('therefore', 244),
#  ('source', 243),
#  ('recently', 243),
#  ('advantage', 243),
#  ('regard', 243),
#  ('fun', 243),
#  ('information', 242),
#  ('process', 242),
#  ('somewhere', 241),
#  ('offer', 241),
#  ('wasn', 241),
#  ('zero', 240),
#  ('fix', 240),
#  ('general', 240),
#  ('stability', 240),
#  ('card', 239),
#  ('seriously', 239),
#  ('suppose', 239),
#  ('along', 238),
#  ('sooner', 238),
#  ('provide', 238),
#  ('involve', 238),
#  ('trillion', 238),
#  ('attack', 237),
#  ('address', 236),
#  ('global', 233),
#  ('basically', 233),
#  ('mostly', 233),
#  ('ahead', 232),
#  ('barrier', 231),
#  ('quote', 231),
#  ('weak', 231),
#  ('idiot', 230),
#  ('technical', 230),
#  ('totally', 230),
#  ('hundred', 229),
#  ('everybody', 229),
#  ('story', 229),
#  ('hell', 227),
#  ('height', 227),
#  ('face', 226),
#  ('main', 226),
#  ('adopt', 226),
#  ('content', 225),
#  ('manipulation', 225),
#  ('customer', 225),
#  ('require', 225),
#  ('pop', 224),
#  ('count', 224),
#  ('graph', 224),
#  ('hodl', 223),
#  ('coinbase', 222),
#  ('theory', 222),
#  ('reserve', 222),
#  ('mainstream', 221),
#  ('accord', 221),
#  ('three', 221),
#  ('development', 221),
#  ('paper', 220),
#  ('wow', 220),
#  ('june', 220),
#  ('digital', 219),
#  ('funny', 219),
#  ('obvious', 218),
#  ('youtube', 218),
#  ('catch', 218),
#  ('core', 218),
#  ('climb', 217),
#  ('highly', 217),
#  ('excite', 217),
#  ('pattern', 215),
#  ('tend', 214),
#  ('shoot', 214),
#  ('forward', 214),
#  ('present', 213),
#  ('luck', 212),
#  ('beyond', 211),
#  ('pick', 211),
#  ('benefit', 211),
#  ('upload', 211),
#  ('google', 210),
#  ('floor', 210),
#  ('rule', 209),
#  ('stabilize', 208),
#  ('player', 208),
#  ('ignore', 207),
#  ('link', 206),
#  ('fine', 206),
#  ('extremely', 206),
#  ('repeat', 206),
#  ('profitable', 204),
#  ('swing', 203),
#  ('expensive', 203),
#  ('speculative', 203),
#  ('public', 202),
#  ('name', 202),
#  ('honest', 202),
#  ('amaze', 202),
#  ('entire', 202),
#  ('speak', 202),
#  ('ethereum', 201),
#  ('cant', 200),
#  ('argument', 200),
#  ('appear', 199),
#  ('anytime', 199),
#  ('note', 199),
#  ('info', 199),
#  ('christmas', 199),
#  ('flow', 197),
#  ('ltc', 197),
#  ('bot', 196),
#  ('project', 196),
#  ('credit', 196),
#  ('reasonable', 195),
#  ('convert', 195),
#  ('often', 194),
#  ('patience', 194),
#  ('withdraw', 194),
#  ('job', 194),
#  ('img', 194),
#  ('available', 193),
#  ('choose', 193),
#  ('pass', 193),
#  ('stand', 193),
#  ('survive', 193),
#  ('scam', 192),
#  ('segwitx', 191),
#  ('guarantee', 191),
#  ('afford', 191),
#  ('balance', 190),
#  ('manage', 190),
#  ('except', 190),
#  ('key', 190),
#  ('relate', 189),
#  ('attention', 189),
#  ('adopter', 189),
#  ('street', 188),
#  ('hedge', 187),
#  ('silver', 187),
#  ('del', 187),
#  ('sale', 187),
#  ('alone', 186),
#  ('prepare', 186),
#  ('sometimes', 186),
#  ('suddenly', 185),
#  ('expectation', 185),
#  ('computer', 185),
#  ('gamble', 184),
#  ('party', 184),
#  ('cool', 184),
#  ('leverage', 184),
#  ('non', 183),
#  ('lucky', 183),
#  ('list', 182),
#  ('sentiment', 182),
#  ('ride', 182),
#  ('statement', 181),
#  ('house', 181),
#  ('confirm', 181),
#  ('absolutely', 181),
#  ('october', 181),
#  ('immediately', 180),
#  ('join', 180),
#  ('wp', 180),
#  ('concern', 179),
#  ('update', 179),
#  ('deep', 179),
#  ('accumulate', 179),
#  ('security', 179),
#  ('board', 178),
#  ('nearly', 178),
#  ('estimate', 177),
#  ('february', 176),
#  ('surge', 175),
#  ('cover', 175),
#  ('clearly', 175),
#  ('honestly', 175),
#  ('reduce', 174),
#  ('upward', 174),
#  ('stage', 174),
#  ('fake', 172),
#  ('fair', 172),
#  ('attempt', 172),
#  ('decade', 172),
#  ('plus', 171),
#  ('secure', 171),
#  ('group', 171),
#  ('directly', 170),
#  ('popular', 170),
#  ('cryptocurrencies', 170),
#  ('hardware', 170),
#  ('deposit', 169),
#  ('regret', 169),
#  ('hash', 168),
#  ('solve', 168),
#  ('influence', 168),
#  ('method', 168),
#  ('postimg', 168),
#  ('wake', 168),
#  ('risky', 167),
#  ('night', 167),
#  ('mistake', 167),
#  ('rocket', 167),
#  ('eth', 167),
#  ('upcoming', 166),
#  ('develop', 166),
#  ('choice', 165),
#  ('useful', 165),
#  ('sudden', 165),
#  ('cycle', 165),
#  ('fool', 164),
#  ('pt', 164),
#  ('economic', 164),
#  ('complete', 164),
#  ('area', 164),
#  ('paypal', 164),
#  ('phase', 164),
#  ('burst', 163),
#  ('decent', 162),
#  ('product', 162),
#  ('damn', 162),
#  ('convince', 162),
#  ('em', 162),
#  ('somehow', 162),
#  ('opposite', 161),
#  ('advice', 161),
#  ('trigger', 161),
#  ('forever', 161),
#  ('eye', 161),
#  ('scheme', 160),
#  ('solid', 160),
#  ('purpose', 160),
#  ('sky', 160),
#  ('perfect', 159),
#  ('report', 158),
#  ('common', 158),
#  ('euro', 158),
#  ('slightly', 158),
#  ('pas', 158),
#  ('alternative', 158),
#  ('hasn', 158),
#  ('regulation', 157),
#  ('prefer', 157),
#  ('picture', 157),
#  ('round', 157),
#  ('anywhere', 156),
#  ('millionaire', 156),
#  ('kill', 156),
#  ('road', 156),
#  ('solution', 156),
#  ('litecoin', 155),
#  ('replace', 154),
#  ('avoid', 154),
#  ('plenty', 154),
#  ('september', 153),
#  ('record', 153),
#  ('bitcoincharts', 153),
#  ('website', 152),
#  ('signal', 152),
#  ('trap', 152),
#  ('exact', 151),
#  ('focus', 151),
#  ('eat', 151),
#  ('self', 150),
#  ('momentum', 150),
#  ('percentage', 150),
#  ('sustain', 150),
#  ('text', 149),
#  ('despite', 149),
#  ('logic', 149),
#  ('release', 149),
#  ('cent', 149),
#  ('protocol', 148),
#  ('maximum', 148),
#  ('afraid', 147),
#  ('approach', 147),
#  ('original', 147),
#  ('settle', 147),
#  ('promise', 147),
#  ('equal', 147),
#  ('bitpay', 147),
#  ('steal', 147),
#  ('central', 146),
#  ('act', 146),
#  ('cut', 146),
#  ('train', 145),
#  ('hey', 145),
#  ('fully', 145),
#  ('throw', 145),
#  ('law', 144),
#  ('determine', 144),
#  ('confidence', 144),
#  ('discussion', 144),
#  ('max', 144),
#  ('electricity', 144),
#  ('commodity', 143),
#  ('rebound', 143),
#  ('listen', 143),
#  ('proof', 143),
#  ('faith', 143),
#  ('lack', 143),
#  ('assumption', 143),
#  ('debt', 143),
#  ('couldn', 142),
#  ('fluctuation', 142),
#  ('math', 142),
#  ('together', 142),
#  ('local', 141),
#  ('remove', 141),
#  ('human', 141),
#  ('ponzi', 141),
#  ('apple', 140),
#  ('overall', 140),
#  ('draw', 140),
#  ('tech', 140),
#  ('research', 139),
#  ('green', 139),
#  ('shouldn', 139),
#  ('print', 139),
#  ('middle', 139),
#  ('uptrend', 138),
#  ('bch', 138),
#  ('piece', 137),
#  ('insane', 137),
#  ('ton', 136),
#  ('burn', 136),
#  ('model', 136),
#  ('wise', 136),
#  ('handle', 135),
#  ('goal', 135),
#  ('admit', 135),
#  ('downtrend', 135),
#  ('us', 134),
#  ('newbie', 134),
#  ('blow', 134),
#  ('withdrawal', 134),
#  ('unfortunately', 134),
#  ('file', 134),
#  ('confident', 134),
#  ('valuation', 133),
#  ('bill', 133),
#  ('liquidity', 133),
#  ('dumb', 133),
#  ('warn', 132),
#  ('page', 132),
#  ('btw', 132),
#  ('haha', 132),
#  ('upwards', 132),
#  ('manipulator', 132),
#  ('fairly', 132),
#  ('sum', 132),
#  ('co', 131),
#  ('personal', 131),
#  ('extra', 131),
#  ('stamp', 131),
#  ('ridiculous', 131),
#  ('relatively', 131),
#  ('atm', 131),
#  ('liquidate', 130),
#  ('individual', 130),
#  ('private', 130),
#  ('speed', 130),
#  ('skyrocket', 130),
#  ('meet', 130),
#  ('somebody', 130),
#  ('fill', 129),
#  ('success', 129),
#  ('exponential', 129),
#  ('destroy', 129),
#  ('maintain', 129),
#  ('sad', 129),
#  ('receive', 128),
#  ('decoration', 128),
#  ('joke', 128),
#  ('god', 128),
#  ('arbitrage', 128),
#  ('approve', 128),
#  ('underline', 127),
#  ('progress', 127),
#  ('everyday', 127),
#  ('morning', 127),
#  ('track', 127),
#  ('generally', 127),
#  ('press', 127),
#  ('blog', 127),
#  ('suspect', 126),
#  ('switch', 126),
#  ('unpredictable', 126),
#  ('red', 126),
#  ('sustainable', 126),
#  ('awesome', 126),
#  ('outside', 125),
#  ('implement', 125),
#  ('recovery', 125),
#  ('final', 125),
#  ('activity', 124),
#  ('effort', 124),
#  ('significantly', 124),
#  ('disagree', 124),
#  ...]

# %% [markdown]
# # LDA

# %%
import gensim

# %%
import datetime

# %%
from gensim import corpora, models

a = datetime.datetime.now()

dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

b = datetime.datetime.now()
c = b - a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4cd105ca0445> in <module>()
#       3 a = datetime.datetime.now()
#       4
# ----> 5 dictionary = corpora.Dictionary(texts)
#       6 corpus = [dictionary.doc2bow(text) for text in texts]
#       7
#
# NameError: name 'texts' is not defined

# %%
print(c)
# Out:
# 0:00:19.882806

# %%
a = datetime.datetime.now()
damodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=15, id2word = dictionary, passes=20)
b = datetime.datetime.now()
c = b - a

# %%
print( c)
# Out:
# 0:04:26.926923

# %%
from sklearn.externals import joblib
# joblib.dump(damodel, 'LDA_model.pkl')

# %%
damodel = joblib.load('LDA_model.pkl')

# %%
damodel.get_document_topics
# Out:
# [(173, 0.038102824),
#  (175, 0.022032823),
#  (281, 0.015734375),
#  (42, 0.011334545),
#  (118, 0.0071779178),
#  (678, 0.0066948608),
#  (508, 0.006389695),
#  (36, 0.0063665253),
#  (119, 0.0063250996),
#  (535, 0.005789681)]

# %%
["m", "import",  "import", "http", "li", "b", "style" , "font", "span","hr", "d" , "jpg", "png" ]
# Out:
# ['m',
#  'import',
#  'import',
#  'http',
#  'li',
#  'b',
#  'style',
#  'font',
#  'span',
#  'hr',
#  'd',
#  'jpg',
#  'png']

# %%
'imageshack', 'pt', 'em', 'img'

# %%
# get LDA topics:
for i in damodel.print_topics(num_topics=50, num_words=10):
    print(i)
    print('-----------------')
# Out:
# (0, '0.038*"china" + 0.022*"chinese" + 0.016*"exchange" + 0.011*"news" + 0.007*"ban" + 0.007*"time" + 0.006*"people" + 0.006*"like" + 0.006*"bank" + 0.006*"price"')
# -----------------
# (1, '0.016*"spend" + 0.015*"double" + 0.011*"blockchain" + 0.010*"transaction" + 0.008*"fork" + 0.007*"chain" + 0.006*"address" + 0.005*"see" + 0.005*"info" + 0.004*"merchant"')
# -----------------
# (2, '0.020*"price" + 0.015*"go" + 0.011*"market" + 0.009*"see" + 0.009*"low" + 0.008*"bitcoin" + 0.007*"buy" + 0.007*"back" + 0.007*"time" + 0.007*"day"')
# -----------------
# (3, '0.018*"buy" + 0.014*"bitcoin" + 0.013*"sell" + 0.012*"price" + 0.011*"go" + 0.009*"coin" + 0.009*"people" + 0.008*"like" + 0.008*"time" + 0.007*"make"')
# -----------------
# (4, '0.015*"bitcoinica" + 0.008*"market" + 0.006*"one" + 0.006*"short" + 0.006*"people" + 0.006*"make" + 0.005*"go" + 0.005*"position" + 0.005*"don" + 0.005*"like"')
# -----------------
# (5, '0.011*"price" + 0.009*"bitcoin" + 0.009*"people" + 0.008*"go" + 0.007*"year" + 0.007*"like" + 0.007*"value" + 0.007*"one" + 0.006*"time" + 0.006*"market"')
# -----------------
# (6, '0.083*"inherit" + 0.042*"top" + 0.040*"valign" + 0.011*"bitpay" + 0.010*"india" + 0.008*"payment" + 0.006*"volume" + 0.005*"merchant" + 0.005*"transaction" + 0.005*"fee"')
# -----------------
# (7, '0.030*"prediction" + 0.016*"guess" + 0.015*"price" + 0.012*"win" + 0.010*"go" + 0.009*"july" + 0.008*"predict" + 0.007*"june" + 0.007*"see" + 0.006*"halve"')
# -----------------
# (8, '0.013*"bubble" + 0.012*"chart" + 0.008*"bitcoin" + 0.008*"go" + 0.005*"price" + 0.005*"like" + 0.005*"bitcoincharts" + 0.005*"next" + 0.005*"dell" + 0.005*"mtgoxusd"')
# -----------------
# (9, '0.050*"price" + 0.019*"go" + 0.016*"year" + 0.016*"rise" + 0.015*"see" + 0.014*"happen" + 0.013*"time" + 0.011*"reach" + 0.010*"people" + 0.009*"high"')
# -----------------
# (10, '0.007*"go" + 0.005*"people" + 0.004*"money" + 0.004*"time" + 0.004*"good" + 0.004*"look" + 0.004*"like" + 0.003*"inflation" + 0.003*"say" + 0.003*"deflation"')
# -----------------
# (11, '0.022*"fork" + 0.013*"buy" + 0.011*"go" + 0.010*"august" + 0.008*"happen" + 0.008*"price" + 0.007*"wallet" + 0.007*"coin" + 0.007*"split" + 0.006*"time"')
# -----------------
# (12, '0.005*"tonycoleby" + 0.004*"blockstream" + 0.004*"bitcoingrowth" + 0.003*"imgflip" + 0.002*"rmb" + 0.002*"devs" + 0.002*"beyond" + 0.002*"core" + 0.002*"frmie" + 0.002*"water"')
# -----------------
# (13, '0.010*"like" + 0.009*"people" + 0.008*"go" + 0.007*"make" + 0.006*"bitcoin" + 0.006*"don" + 0.005*"know" + 0.005*"time" + 0.005*"one" + 0.005*"see"')
# -----------------
# (14, '0.008*"wp" + 0.008*"upload" + 0.007*"content" + 0.006*"image" + 0.006*"bull" + 0.006*"org" + 0.006*"view" + 0.005*"greece" + 0.005*"gifsoup" + 0.005*"dance"')
# -----------------

# %%
from itertools import chain
# Assigns the topics to the documents in corpus
lda_corpus = damodel[corpus]

# Find the threshold, let's set the threshold to be 1/#clusters,
# To prove that the threshold is sane, we average the sum of all probabilities:
scores = list(chain(*[[score for topic_id,score in topic] for topic in [doc for doc in lda_corpus]]))
threshold = sum(scores)/len(scores)
print (threshold)
print()

# cluster1 = [j for i,j in zip(lda_corpus,texts) if i[0][1] > threshold]
# cluster2 = [j for i,j in zip(lda_corpus,texts) if i[1][1] > threshold]
# cluster3 = [j for i,j in zip(lda_corpus,texts) if i[2][1] > threshold]
# cluster4 = [j for i,j in zip(lda_corpus,texts) if i[3][1] > threshold]
# cluster5 = [j for i,j in zip(lda_corpus,texts) if i[4][1] > threshold]

# print (cluster1)
# print( cluster2)
# print( cluster3)
# print( cluster4)
# print( cluster5)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-58087c34d334> in <module>()
#       5 # Find the threshold, let's set the threshold to be 1/#clusters,
#       6 # To prove that the threshold is sane, we average the sum of all probabilities:
# ----> 7 scores = list(chain(*[[score for topic_id,score in topic] for topic in [doc for doc in lda_corpus]]))
#       8 threshold = sum(scores)/len(scores)
#       9 print (threshold)
#
# <ipython-input-39-58087c34d334> in <listcomp>(.0)
#       5 # Find the threshold, let's set the threshold to be 1/#clusters,
#       6 # To prove that the threshold is sane, we average the sum of all probabilities:
# ----> 7 scores = list(chain(*[[score for topic_id,score in topic] for topic in [doc for doc in lda_corpus]]))
#       8 threshold = sum(scores)/len(scores)
#       9 print (threshold)
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/interfaces.py in __iter__(self)
#     123         else:
#     124             for doc in self.corpus:
# --> 125                 yield self.obj[doc]
#     126
#     127     def __getitem__(self, docno):
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py in __getitem__(self, bow, eps)
#    1185             `(topic_id, topic_probability)` 2-tuples.
#    1186         """
# -> 1187         return self.get_document_topics(bow, eps, self.minimum_phi_value, self.per_word_topics)
#    1188
#    1189     def save(self, fname, ignore=('state', 'dispatcher'), separately=None, *args, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py in get_document_topics(self, bow, minimum_probability, minimum_phi_value, per_word_topics)
#    1022             return self._apply(corpus, **kwargs)
#    1023
# -> 1024         gamma, phis = self.inference([bow], collect_sstats=per_word_topics)
#    1025         topic_dist = gamma[0] / sum(gamma[0])  # normalize distribution
#    1026
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py in inference(self, chunk, collect_sstats)
#     506             Elogthetad = Elogtheta[d, :]
#     507             expElogthetad = expElogtheta[d, :]
# --> 508             expElogbetad = self.expElogbeta[:, ids]
#     509
#     510             # The optimal phi_{dwk} is proportional to expElogthetad_k * expElogbetad_w.
#
# IndexError: index 119317 is out of bounds for axis 1 with size 119317

# %%
print(damodel.print_topics(num_topics=10, num_words=20))
# Out:
# [(0, '0.040*"bitcoin" + 0.012*"peopl" + 0.011*"can" + 0.009*"btc" + 0.008*"use" + 0.008*"like" + 0.007*"money" + 0.007*"just" + 0.007*"think" + 0.006*"get" + 0.006*"coin" + 0.006*"one" + 0.006*"currenc" + 0.006*"make" + 0.006*"don" + 0.005*"valu" + 0.005*"price" + 0.005*"market" + 0.005*"exchang" + 0.005*"go"'), (1, '0.042*"0" + 0.042*"span" + 0.039*"32" + 0.034*"1" + 0.029*"btc" + 0.024*"style" + 0.021*"font" + 0.019*"b" + 0.018*"import" + 0.018*"3em" + 0.018*"height" + 0.018*"size" + 0.018*"line" + 0.016*"36" + 0.012*"http" + 0.012*"li" + 0.011*"12pt" + 0.010*"whaleclub" + 0.009*"co" + 0.009*"hr"'), (2, '0.007*"1" + 0.007*"d" + 0.007*"0" + 0.007*"jpg" + 0.007*"png" + 0.006*"http" + 0.006*"org" + 0.005*"like" + 0.005*"chart" + 0.005*"m" + 0.005*"b" + 0.004*"2" + 0.004*"one" + 0.004*"post" + 0.004*"just" + 0.004*"imgur" + 0.004*"can" + 0.004*"look" + 0.004*"5" + 0.004*"use"'), (3, '0.056*"bitcoin" + 0.050*"price" + 0.015*"think" + 0.014*"year" + 0.014*"can" + 0.014*"now" + 0.013*"go" + 0.012*"time" + 0.011*"happen" + 0.010*"see" + 0.009*"increas" + 0.009*"buy" + 0.009*"rise" + 0.008*"peopl" + 0.008*"just" + 0.008*"reach" + 0.006*"good" + 0.006*"end" + 0.005*"like" + 0.005*"month"'), (4, '0.017*"price" + 0.014*"buy" + 0.012*"sell" + 0.011*"go" + 0.010*"just" + 0.009*"now" + 0.009*"market" + 0.009*"btc" + 0.008*"time" + 0.008*"like" + 0.007*"bitcoin" + 0.007*"can" + 0.007*"think" + 0.006*"get" + 0.006*"back" + 0.006*"peopl" + 0.006*"see" + 0.006*"coin" + 0.006*"don" + 0.006*"trade"')]

# %%
for x in ldamodel.print_topics(num_topics=5, num_words=15):
    print(x)
# Out:
# (0, '0.011*"will" + 0.010*"999" + 0.010*"price" + 0.009*"s" + 0.009*"market" + 0.009*"nbsp" + 0.008*"t" + 0.008*"http" + 0.007*"see" + 0.007*"go" + 0.006*"like" + 0.006*"com" + 0.006*"bitcoin" + 0.006*"now" + 0.006*"time"')
# (1, '0.028*"price" + 0.024*"will" + 0.015*"nbsp" + 0.014*"halv" + 0.013*"go" + 0.011*"think" + 0.010*"http" + 0.009*"t" + 0.009*"now" + 0.009*"see" + 0.008*"bitcoin" + 0.008*"com" + 0.007*"s" + 0.007*"400" + 0.007*"500"')
# (2, '0.018*"nbsp" + 0.014*"bitcoin" + 0.013*"t" + 0.012*"s" + 0.009*"will" + 0.009*"btc" + 0.008*"just" + 0.007*"buy" + 0.007*"price" + 0.007*"can" + 0.007*"peopl" + 0.007*"like" + 0.006*"go" + 0.006*"get" + 0.006*"market"')
# (3, '0.072*"nbsp" + 0.015*"amp" + 0.015*"bitcoin" + 0.010*"s" + 0.010*"http" + 0.009*"t" + 0.008*"will" + 0.008*"1" + 0.007*"btc" + 0.006*"com" + 0.006*"0" + 0.005*"use" + 0.005*"can" + 0.005*"like" + 0.005*"9617"')
# (4, '0.045*"bitcoin" + 0.035*"will" + 0.034*"price" + 0.012*"think" + 0.012*"can" + 0.012*"year" + 0.011*"s" + 0.011*"now" + 0.011*"t" + 0.010*"go" + 0.009*"happen" + 0.009*"time" + 0.009*"peopl" + 0.009*"just" + 0.008*"see"')

# %%
ldamodel.get_document_topics(corpus[1])
# Out:
# [(2, 0.99671769)]

# %% [markdown]
# -----------------

# %%
list_message[0]
# Out:
# 'Even before I saw how much impact the upcoming fork was having I predicted 6-7K easily by end of year.&nbsp; Much more news about BTC and a lot more adoption.      Now with Fork getting closer everyone is dumping alt coins to buy BTC and get the "free"&nbsp; BTG coins.&nbsp; Has created a selling of alt coin and buying frenzy of BTC.               I dumped a decent amount into alt coins in the last week as they had dropped 25-60% in about 7 days across the board.&nbsp; Sure makes for a great buying opportunity of alt coins.&nbsp;      You get alts for cheaper and added value of your BTC to buy them with.&nbsp;           BTC is up $1470 since last week&nbsp; :o&nbsp; &nbsp;Smashed through 5K barrier like it didn\'t exist. I dont see 6K being a barrier either with this kind of frenzy. 7K is likely and I wouldn\'t be surprised at all to see it touch 8K. There is BTC Gold in them thar hills........&nbsp; &nbsp;;D                    &nbsp; 1470 in 1 week is huge, massive.     Next step is 7000.'

# %%
texts = []
for msg in range(len(list_message)):
    # Convert the document into lowercase
    raw = list_message[msg].lower()
    # Tokenize the document: tokens
    tokens = tokenizer.tokenize(raw)
    
    stopped_tokens = [i for i in tokens if not i in en_stop]
    stopped_tokens = [i for i in stopped_tokens if not i in remove_words]
    stemmed_tokens = [p_stemmer.stem(i) for i in stopped_tokens]
    texts.append(stemmed_tokens)

# %%
# Import Dictionary
from gensim.corpora.dictionary import Dictionary

# Create a Dictionary from the articles: dictionary
dictionary = Dictionary(articles)

# Select the id for "computer": computer_id
computer_id = dictionary.token2id.get("computer")

# Use computer_id with the dictionary to print the word
print(dictionary.get(computer_id))

# Create a MmCorpus: corpus
corpus = [dictionary.doc2bow(article) for article in articles]

# Print the first 10 word ids with their frequency counts from the fifth document
print(corpus[4][:10])
corpus[0]

# %%
# Save the fifth document: doc
doc = corpus[4]

# Sort the doc for frequency: bow_doc
bow_doc = sorted(doc, key=lambda w: w[1], reverse=True)

# Print the top 5 words of the document alongside the count
for word_id, word_count in bow_doc[:5]:
    print(dictionary.get(word_id), word_count)
    
# Create the defaultdict: total_word_count
total_word_count = defaultdict(int)
for word_id, word_count in itertools.chain.from_iterable(corpus):
    total_word_count[word_id] += word_count

# Create a sorted list from the defaultdict: sorted_word_count 
sorted_word_count = sorted(total_word_count.items(), key=lambda w: w[1], reverse=True) 

# Print the top 5 words across all documents alongside the count
for word_id, word_count in sorted_word_count[:5]:
    print(dictionary.get(word_id), word_count)

# %%
df = pd.read_csv("pos_neg.csv")

# %%
df
# Out:
#        Unnamed: 0   timestamp  category_id  topic_id  \
# 0               0  1514379921           57   2653937
# 1               1  1514380918           57   2653937
# 2               2  1514381025           57   2653937
# 3               3  1514382464           57   2653937
# 4               4  1514384271           57   2653937
# 5               5  1514390315           57   2653937
# 6               6  1514393063           57   2653937
# 7               7  1514395791           57   2653937
# 8               8  1514397927           57   2653937
# 9               9  1514405189           57   2653937
# 10             10  1514406032           57   2653937
# 11             11  1514406610           57   2653937
# 12             12  1514410009           57   2653937
# 13             13  1514410766           57   2653937
# 14             14  1514415494           57   2653937
# 15             15  1514421884           57   2653937
# 16             16  1514430495           57   2653937
# 17             17  1514431092           57   2653937
# 18             18  1514444309           57   2653937
# 19             19  1514444502           57   2653937
# 20             20  1514444604           57   2653937
# 21             21  1514444721           57   2653937
# 22             22  1514444976           57   2653937
# 23             23  1514445045           57   2653937
# 24             24  1514445132           57   2653937
# 25             25  1514445325           57   2653937
# 26             26  1514445881           57   2653937
# 27             27  1514449243           57   2653937
# 28             28  1514572926           57   2653937
# 29             29  1514575234           57   2653937
# ...           ...         ...          ...       ...
# 41298       41298  1412570192           57    812673
# 41299       41299  1412571256           57    812673
# 41300       41300  1412453408           57    811372
# 41301       41301  1412453745           57    811372
# 41302       41302  1412454228           57    811372
# 41303       41303  1412454542           57    811372
# 41304       41304  1412454553           57    811372
# 41305       41305  1412454702           57    811372
# 41306       41306  1412454793           57    811372
# 41307       41307  1412455847           57    811372
# 41308       41308  1412457176           57    811372
# 41309       41309  1412457358           57    811372
# 41310       41310  1412457402           57    811372
# 41311       41311  1412457739           57    811372
# 41312       41312  1412457970           57    811372
# 41313       41313  1412480503           57    811372
# 41314       41314  1412481430           57    811372
# 41315       41315  1412481698           57    811372
# 41316       41316  1412482222           57    811372
# 41317       41317  1412484213           57    811372
# 41318       41318  1412484407           57    811372
# 41319       41319  1412485388           57    811372
# 41320       41320  1412487863           57    811372
# 41321       41321  1412496732           57    811372
# 41322       41322  1411049957           57    787222
# 41323       41323  1411050454           57    787222
# 41324       41324  1411050918           57    787222
# 41325       41325  1411051112           57    787222
# 41326       41326  1411075852           57    787222
# 41327       41327  1411075887           57    787222
#
#                                         topic_title  message_number  \
# 0      16.5K will be the major resistance for BTC ?               1
# 1      16.5K will be the major resistance for BTC ?               2
# 2      16.5K will be the major resistance for BTC ?               3
# 3      16.5K will be the major resistance for BTC ?               4
# 4      16.5K will be the major resistance for BTC ?               5
# 5      16.5K will be the major resistance for BTC ?               6
# 6      16.5K will be the major resistance for BTC ?               7
# 7      16.5K will be the major resistance for BTC ?               8
# 8      16.5K will be the major resistance for BTC ?               9
# 9      16.5K will be the major resistance for BTC ?              10
# 10     16.5K will be the major resistance for BTC ?              11
# 11     16.5K will be the major resistance for BTC ?              12
# 12     16.5K will be the major resistance for BTC ?              13
# 13     16.5K will be the major resistance for BTC ?              14
# 14     16.5K will be the major resistance for BTC ?              15
# 15     16.5K will be the major resistance for BTC ?              16
# 16     16.5K will be the major resistance for BTC ?              17
# 17     16.5K will be the major resistance for BTC ?              18
# 18     16.5K will be the major resistance for BTC ?              19
# 19     16.5K will be the major resistance for BTC ?              20
# 20     16.5K will be the major resistance for BTC ?              21
# 21     16.5K will be the major resistance for BTC ?              22
# 22     16.5K will be the major resistance for BTC ?              23
# 23     16.5K will be the major resistance for BTC ?              24
# 24     16.5K will be the major resistance for BTC ?              25
# 25     16.5K will be the major resistance for BTC ?              26
# 26     16.5K will be the major resistance for BTC ?              27
# 27     16.5K will be the major resistance for BTC ?              28
# 28     16.5K will be the major resistance for BTC ?              29
# 29     16.5K will be the major resistance for BTC ?              30
# ...                                             ...             ...
# 41298                                            ..               2
# 41299                                            ..               3
# 41300                                             .               1
# 41301                                             .               2
# 41302                                             .               3
# 41303                                             .               4
# 41304                                             .               5
# 41305                                             .               6
# 41306                                             .               7
# 41307                                             .               8
# 41308                                             .               9
# 41309                                             .              10
# 41310                                             .              11
# 41311                                             .              12
# 41312                                             .              13
# 41313                                             .              14
# 41314                                             .              15
# 41315                                             .              16
# 41316                                             .              17
# 41317                                             .              18
# 41318                                             .              19
# 41319                                             .              20
# 41320                                             .              21
# 41321                                             .              22
# 41322                                             .               1
# 41323                                             .               2
# 41324                                             .               3
# 41325                                             .               4
# 41326                                             .               5
# 41327                                             .               6
#
#          message_author                                       message_text  \
# 0       AICoin_Official  As you can see, price started a correction imm...
# 1                nokati  And&nbsp; who is this Kuang Ren with such a wi...
# 2              fabiorem  Yes, theres a lot of resistance at this level,...
# 3            heringasem  With the current price fluctuations the price ...
# 4             CuDoCuDau                             You should buy bitcoin
# 5            BrewMaster  there are currently a couple of things going o...
# 6             CuDoCuDau      I think btc will increase $30000 in next year
# 7             Yaunfitda       In my view, $16K is another barrier that ...
# 8              mrcash02  Bitcoin has already hit $19.000 previously. No...
# 9                Gaaara       Nope I guess that can only happen after t...
# 10            player514       I think it's interesting how the drop/cor...
# 11               Eternu  Like always, for steady price time has to pass...
# 12             joinfree       It seems that the floor is going to be in...
# 13             sopromat  I think that this is going to be the new all t...
# 14           BlackPanda  Some time ago there has been a decline in bitc...
# 15           dothebeats  A huge one at that tbh, knowing that we've rea...
# 16            michellee  I am not sure that bitcoin could reach $16,5K ...
# 17             mrcash02       Well, I have already seen BTC rising more...
# 18      AICoin_Official  He is one of the famous analyst in Chinese cry...
# 19      AICoin_Official  What may have built these resistance levels? A...
# 20      AICoin_Official  Yes, really annoying, 1 hour before, 16.8K, ni...
# 21      AICoin_Official  Though not so much, I do own BTC, thank you fo...
# 22      AICoin_Official  I think retail traders may have no such power ...
# 23      AICoin_Official  You mean it will increase by $30000 or to $300...
# 24      AICoin_Official  Well, you must buy BTCs below 10K, right? No b...
# 25      AICoin_Official  Will you sell part of your BTC chips to lock y...
# 26            WindForce  Well i would first see how do we get to 19-20K...
# 27      AICoin_Official  Well, seems like people in this forum are basi...
# 28             mrcash02       I would sell part of it if Bitcoin reache...
# 29               Aamir1  Not $16.5, but it seems to be $15k for me. Bit...
# ...                 ...                                                ...
# 41298         waterpile              I enjoy reading their speculations :)
# 41299        Rat_Poison       Didn't you hear, bitcoin will raise the w...
# 41300         deadsea33                                                  .
# 41301         Beliathon                                               $300
# 41302             genco  I think lower. Think about it: if price was $2...
# 41303              okae  My guess between 75$-180$ <i>( optimist mode o...
# 41304             Elwar                                               $312
# 41305           Wilhelm                     Thats when he stops selling :P
# 41306           zeroday                          He is... The Manipulator!
# 41307              Amph  i want to throw it here          between 200 a...
# 41308             d5000                     2000 ...               ...CNY.
# 41309             Odalv                      bottom is above $290 ..
# 41310        exocytosis  Zero. That's the true price BTC is trying to f...
# 41311           ravenjt       Youve changed your tune. You used to say ...
# 41312              Amph       the 350 was a first step, never said it w...
# 41313             d5000       Approximately yes, but it doesn't matter,...
# 41314         DieJohnny       as good as any, i like it, but i am not o...
# 41315            cbeast  Bitcoin needed this. That volume is so low tha...
# 41316            akujin  <a href="http://i.imgur.com/rPiraYG.jpg">http:...
# 41317         orpington  The bottom will be between $250 - $300.       ...
# 41318      mailmansDOGE  There is no bottom price sadly. The sky is the...
# 41319            cbeast  <a href="http://i.imgur.com/8D1BsTU.png">http:...
# 41320          ellen_me  I voted for $300, just like to be positive thi...
# 41321         Vlad2Vlad            ~$278 in the next 48 hours, which sh...
# 41322     cryptoart.com                                                  .
# 41323           Hfertig       And back down to 8365 without a short squ...
# 41324              klee                    So what is their next move? Up?
# 41325           Hfertig       Difficult to say. Selling pressure is sti...
# 41326         molecular       doesn't the same go for the $20 millions ...
# 41327  grappa_barricata  If i may add something, a sizable part of the ...
#
#                                              quoteheader    pos    neg    neu  \
# 0                                                    NaN  0.082  0.041  0.876
# 1                                                     []  0.112  0.033  0.854
# 2                                                     []  0.110  0.000  0.890
# 3                                                     []  0.127  0.058  0.815
# 4      ['<div class="quoteheader"><a href="https://bi...  0.000  0.000  1.000
# 5                                                     []  0.169  0.000  0.831
# 6      ['<div class="quoteheader"><a href="https://bi...  0.247  0.000  0.753
# 7      ['<div class="quoteheader"><a href="https://bi...  0.128  0.113  0.759
# 8                                                     []  0.123  0.029  0.848
# 9      ['<div class="quoteheader"><a href="https://bi...  0.090  0.020  0.889
# 10     ['<div class="quoteheader"><a href="https://bi...  0.126  0.033  0.842
# 11                                                    []  0.178  0.000  0.822
# 12     ['<div class="quoteheader"><a href="https://bi...  0.089  0.093  0.819
# 13                                                    []  0.039  0.079  0.882
# 14     ['<div class="quoteheader"><a href="https://bi...  0.233  0.000  0.767
# 15                                                    []  0.080  0.038  0.882
# 16                                                    []  0.136  0.043  0.821
# 17     ['<div class="quoteheader"><a href="https://bi...  0.100  0.047  0.854
# 18     ['<div class="quoteheader"><a href="https://bi...  0.137  0.000  0.863
# 19     ['<div class="quoteheader"><a href="https://bi...  0.000  0.000  1.000
# 20     ['<div class="quoteheader"><a href="https://bi...  0.403  0.199  0.398
# 21     ['<div class="quoteheader"><a href="https://bi...  0.333  0.000  0.667
# 22     ['<div class="quoteheader"><a href="https://bi...  0.000  0.099  0.901
# 23     ['<div class="quoteheader"><a href="https://bi...  0.419  0.000  0.581
# 24     ['<div class="quoteheader"><a href="https://bi...  0.210  0.091  0.700
# 25     ['<div class="quoteheader"><a href="https://bi...  0.132  0.000  0.868
# 26                                                    []  0.149  0.000  0.851
# 27     ['<div class="quoteheader"><a href="https://bi...  0.280  0.000  0.720
# 28     ['<div class="quoteheader"><a href="https://bi...  0.022  0.000  0.978
# 29                                                    []  0.038  0.000  0.962
# ...                                                  ...    ...    ...    ...
# 41298                                                 []    NaN    NaN    NaN
# 41299  ['<div class="quoteheader"><a href="https://bi...    NaN    NaN    NaN
# 41300                                                 []    NaN    NaN    NaN
# 41301  ['<div class="quoteheader"><a href="https://bi...    NaN    NaN    NaN
# 41302                                                 []    NaN    NaN    NaN
# 41303                                                 []    NaN    NaN    NaN
# 41304                                                 []    NaN    NaN    NaN
# 41305  ['<div class="quoteheader"><a href="https://bi...    NaN    NaN    NaN
# 41306                                                 []    NaN    NaN    NaN
# 41307                                                 []    NaN    NaN    NaN
# 41308                                                 []    NaN    NaN    NaN
# 41309                                                 []    NaN    NaN    NaN
# 41310                                                 []    NaN    NaN    NaN
# 41311  ['<div class="quoteheader"><a href="https://bi...    NaN    NaN    NaN
# 41312  ['<div class="quoteheader"><a href="https://bi...    NaN    NaN    NaN
# 41313  ['<div class="quoteheader"><a href="https://bi...    NaN    NaN    NaN
# 41314  ['<div class="quoteheader"><a href="https://bi...    NaN    NaN    NaN
# 41315                                                 []    NaN    NaN    NaN
# 41316                                                 []    NaN    NaN    NaN
# 41317                                                 []    NaN    NaN    NaN
# 41318                                                 []    NaN    NaN    NaN
# 41319                                                 []    NaN    NaN    NaN
# 41320                                                 []    NaN    NaN    NaN
# 41321                                                 []    NaN    NaN    NaN
# 41322                                                 []    NaN    NaN    NaN
# 41323  ['<div class="quoteheader"><a href="https://bi...    NaN    NaN    NaN
# 41324                                                 []    NaN    NaN    NaN
# 41325  ['<div class="quoteheader"><a href="https://bi...    NaN    NaN    NaN
# 41326  ['<div class="quoteheader"><a href="https://bi...    NaN    NaN    NaN
# 41327                                                 []    NaN    NaN    NaN
#
#        compound
# 0        0.9201
# 1        0.7476
# 2        0.2144
# 3        0.4939
# 4        0.0000
# 5        0.8555
# 6        0.3182
# 7        0.5106
# 8        0.9031
# 9        0.5859
# 10       0.7734
# 11       0.9255
# 12      -0.0799
# 13      -0.2087
# 14       0.9849
# 15       0.4215
# 16       0.8770
# 17       0.5859
# 18       0.6901
# 19       0.0000
# 20       0.8024
# 21       0.6705
# 22      -0.2960
# 23       0.8689
# 24       0.4404
# 25       0.4404
# 26       0.2732
# 27       0.8720
# 28       0.0258
# 29       0.2592
# ...         ...
# 41298       NaN
# 41299       NaN
# 41300       NaN
# 41301       NaN
# 41302       NaN
# 41303       NaN
# 41304       NaN
# 41305       NaN
# 41306       NaN
# 41307       NaN
# 41308       NaN
# 41309       NaN
# 41310       NaN
# 41311       NaN
# 41312       NaN
# 41313       NaN
# 41314       NaN
# 41315       NaN
# 41316       NaN
# 41317       NaN
# 41318       NaN
# 41319       NaN
# 41320       NaN
# 41321       NaN
# 41322       NaN
# 41323       NaN
# 41324       NaN
# 41325       NaN
# 41326       NaN
# 41327       NaN
#
# [41328 rows x 13 columns]

# %%
damodel.get_document_topics(corpus[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-d455c6b307ba> in <module>()
# ----> 1 damodel.get_document_topics(corpus[1])
#
# NameError: name 'corpus' is not defined
